# %% [markdown]
# # Анализ источников новостей

# %% [markdown]
# Цель данного исследования: проанализировать источники новостных лент, сравнить рубрики, подумать над возможностью добавление\удаление категорий для проекта "Радар новостей рунета"

# %%
import numpy as np
import pandas as pd
import datetime as DT

# %% [markdown]
# ## gazeta

# %% [markdown]
# Загрузим датасет gazeta. Одновременно сделаем преобразование даты из строки

# %%
dateparse = lambda x: pd.datetime.strptime(x, "%Y-%m-%d %H:%M:%S")

# %%
data_gazeta = pd.read_csv('../data/gazeta.csv',
                      sep=',',
                      index_col=False,
                      escapechar='\\',
                      parse_dates=['date'],
                      date_parser=dateparse,
                      quotechar='\"',
                      error_bad_lines=False)
# Out:
# b'Skipping line 437258: expected 17 fields, saw 20\n'
# b'Skipping line 591054: expected 17 fields, saw 20\n'
# b'Skipping line 780302: expected 17 fields, saw 20\n'
# b'Skipping line 793371: expected 17 fields, saw 20\n'
# b'Skipping line 838172: expected 17 fields, saw 20\n'
# /home/avenon/anaconda2/envs/proj_news_viz/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Проверим преобразование
data_gazeta.dtypes
# Out:
# date           datetime64[ns]
# url                    object
# edition                object
# topics                 object
# authors                object
# title                  object
# text                   object
# reposts_fb             object
# reposts_vk             object
# reposts_ok             object
# reposts_twi            object
# reposts_lj             object
# reposts_tg             object
# likes                  object
# views                  object
# comm_count             object
# dtype: object

# %%
data_gazeta.shape
# Out:
# (865847, 16)

# %%
# Так выглядет датасет gazeta
data_gazeta.head()
# Out:
#                  date                                                url  \
# 0 2008-11-21 15:19:14  https://www.gazeta.ru/news/business/2008/11/21...
# 1 2012-09-27 10:54:51  https://www.gazeta.ru/science/news/2012/09/27/...
# 2 2015-12-01 15:28:45      https://www.gazeta.ru/army/news/7957079.shtml
# 3 2013-04-18 16:42:06  https://www.gazeta.ru/travel/news/2013/04/18/n...
# 4 2012-09-26 13:54:13  https://www.gazeta.ru/politics/news/2012/09/26...
#
#   edition    topics authors  \
# 0       -    Бизнес     NaN
# 1       -     Наука     NaN
# 2       -     Армия     NaN
# 3       -   Новости     NaN
# 4       -  Политика     NaN
#
#                                                title  \
# 0  Госдума сокращает срок действия ставки экспорт...
# 1   Японские физики повторили синтез 113-го элемента
# 2        Times: Россия строит новую авиабазу в Сирии
# 3  Власти Египта гарантируют безопасность российс...
# 4  Гордума Новочеркасска приняла отставку мэра го...
#
#                                                 text reposts_fb reposts_vk  \
# 0  Госдума приняла сегодня в первом чтении и сраз...          -          -
# 1  Японские ученые из физического центра RIKEN за...          -          -
# 2  Россия готовится расширить свою военную операц...          -          -
# 3  Египет ждет российских туристов и гарантирует ...          -          -
# 4  В Ростовской области депутаты гордумы Новочерк...          -          -
#
#   reposts_ok reposts_twi reposts_lj reposts_tg likes views comm_count
# 0          -           -          -          -     -     -          -
# 1          -           -          -          -     -     -          -
# 2          -           -          -          -     -     -          -
# 3          -           -          -          -     -     -          -
# 4          -           -          -          -     -     -          -

# %%
# Выясним в каким столбцах есть пустые данные
data_gazeta.isnull().any()
# Out:
# date           False
# url            False
# edition        False
# topics         False
# authors         True
# title          False
# text           False
# reposts_fb     False
# reposts_vk     False
# reposts_ok     False
# reposts_twi    False
# reposts_lj     False
# reposts_tg     False
# likes          False
# views          False
# comm_count     False
# dtype: bool

# %% [markdown]
# Как видим, в некоторых столбцах вместо значения Nan используется "-", их преобразованием займемся позже. А пока посмотрим строки, в которых пустые тексты новостей

# %%
print('Кол-во строк с значением NaN в столбце "authors" = ', data_gazeta['authors'].isnull().sum())
data_gazeta[data_gazeta['authors'].isnull()]
# Out:
# Кол-во строк с значением NaN в столбце "authors" =  801505
#                       date                                                url  \
# 0      2008-11-21 15:19:14  https://www.gazeta.ru/news/business/2008/11/21...
# 1      2012-09-27 10:54:51  https://www.gazeta.ru/science/news/2012/09/27/...
# 2      2015-12-01 15:28:45      https://www.gazeta.ru/army/news/7957079.shtml
# 3      2013-04-18 16:42:06  https://www.gazeta.ru/travel/news/2013/04/18/n...
# 4      2012-09-26 13:54:13  https://www.gazeta.ru/politics/news/2012/09/26...
# ...                    ...                                                ...
# 862978 2018-07-30 14:23:10  https://www.gazeta.ru/tech/news/2018/07/30/n_1...
# 862979 2018-07-30 16:35:49  https://www.gazeta.ru/tech/news/2018/07/30/n_1...
# 862980 2018-07-30 17:10:28  https://www.gazeta.ru/tech/news/2018/07/30/n_1...
# 862981 2018-07-31 12:42:17  https://www.gazeta.ru/tech/news/2018/07/31/n_1...
# 862982 2018-07-31 17:56:12  https://www.gazeta.ru/tech/news/2018/07/31/n_1...
#
#        edition      topics authors  \
# 0            -      Бизнес     NaN
# 1            -       Наука     NaN
# 2            -       Армия     NaN
# 3            -     Новости     NaN
# 4            -    Политика     NaN
# ...        ...         ...     ...
# 862978       -  Технологии     NaN
# 862979       -  Технологии     NaN
# 862980       -  Технологии     NaN
# 862981       -  Технологии     NaN
# 862982       -  Технологии     NaN
#
#                                                     title  \
# 0       Госдума сокращает срок действия ставки экспорт...
# 1        Японские физики повторили синтез 113-го элемента
# 2             Times: Россия строит новую авиабазу в Сирии
# 3       Власти Египта гарантируют безопасность российс...
# 4       Гордума Новочеркасска приняла отставку мэра го...
# ...                                                   ...
# 862978  Суд в Греции удовлетворил второй запрос России...
# 862979      Песков рассказал, что не пользуется фейсбуком
# 862980   Венедиктов покинул совет директоров «Эха Москвы»
# 862981  Жуткое существо терроризирует пользователей Wh...
# 862982  Редакция российского Forbes обратилась в амери...
#
#                                                      text reposts_fb  \
# 0       Госдума приняла сегодня в первом чтении и сраз...          -
# 1       Японские ученые из физического центра RIKEN за...          -
# 2       Россия готовится расширить свою военную операц...          -
# 3       Египет ждет российских туристов и гарантирует ...          -
# 4       В Ростовской области депутаты гордумы Новочерк...          -
# ...                                                   ...        ...
# 862978  Адвокат ТимофейnМусатовnзаявил, что греческий ...          -
# 862979  Пресс-секретарь президента России ДмитрийnПеск...          -
# 862980  Главный редакторn«Эха Москвы»nАлексейnВенедикт...          -
# 862981  Пользователи WhatsApp из Германии, Испании и р...          -
# 862982  Редакция российскогоnForbesnобратилась в амери...          -
#
#        reposts_vk reposts_ok reposts_twi reposts_lj reposts_tg likes views  \
# 0               -          -           -          -          -     -     -
# 1               -          -           -          -          -     -     -
# 2               -          -           -          -          -     -     -
# 3               -          -           -          -          -     -     -
# 4               -          -           -          -          -     -     -
# ...           ...        ...         ...        ...        ...   ...   ...
# 862978          -          -           -          -          -     -     -
# 862979          -          -           -          -          -     -     -
# 862980          -          -           -          -          -     -     -
# 862981          -          -           -          -          -     -     -
# 862982          -          -           -          -          -     -     -
#
#        comm_count
# 0               -
# 1               -
# 2               -
# 3               -
# 4               -
# ...           ...
# 862978          -
# 862979          -
# 862980          -
# 862981          -
# 862982          -
#
# [801505 rows x 16 columns]

# %%
print('authors: ',data_gazeta['authors'].unique())
# Out:
# authors:  [nan 'Александра Кошкина'
#  'Анастасия Берсенева,Максим Солопов,Константин Новиков,Евгений Сафронов'
#  ... 'Алина Распоповой' 'Анатолий Караваев,Юрий Воронцов'
#  'Евгения Петрова (Сочи)']

# %% [markdown]
# Посмотрим, что в столбцах, которые содержат дефис, как обозначение пустых данных

# %%
print('edition: ',data_gazeta['edition'].unique())
print('reposts_fb: ', data_gazeta['reposts_fb'].unique())
print('reposts_vk: ',data_gazeta['reposts_vk'].unique())
print('reposts_ok: ',data_gazeta['reposts_ok'].unique())
print('reposts_twi: ',data_gazeta['reposts_twi'].unique())
print('reposts_lj: ',data_gazeta['reposts_lj'].unique())
print('reposts_tg: ',data_gazeta['reposts_tg'].unique())
print('likes: ',data_gazeta['likes'].unique())
print('views: ',data_gazeta['views'].unique())
print('comm_count: ',data_gazeta['comm_count'].unique())
# Out:
# edition:  ['-']
# reposts_fb:  ['-']
# reposts_vk:  ['-']
# reposts_ok:  ['-']
# reposts_twi:  ['-']
# reposts_lj:  ['-']
# reposts_tg:  ['-']
# likes:  ['-']
# views:  ['-']
# comm_count:  ['-']

# %% [markdown]
# ### Рубрики gazeta

# %%
# Считаем количество рубрик в данном датасете, а также выведем значения
print('Количество рубрик = ', data_gazeta.topics.unique().shape)
data_gazeta['topics'].unique()
# Out:
# Количество рубрик =  (12,)
# array(['Бизнес', 'Наука', 'Армия', 'Новости', 'Политика', 'Культура',
#        'Спорт', 'Общество', 'Стиль', 'Технологии', 'Авто', 'Мнения'],
#       dtype=object)

# %% [markdown]
# Все рубрики, с количеством новостей в каждой группе

# %%
data_gazeta.groupby('topics')['topics'].count()
# Out:
# topics
# Авто           46477
# Армия          25522
# Бизнес        105386
# Культура       42290
# Мнения           890
# Наука          17258
# Новости        13252
# Общество      163389
# Политика      100214
# Спорт         318908
# Стиль          12875
# Технологии     19386
# Name: topics, dtype: int64
