# %% [markdown]
# # meduza

# %%
from string import punctuation
from collections import Counter
import datetime
import matplotlib.pyplot as plt

# %%
import sys

# %%
sys.path.append('C:\\projects\\datascience\\proj_news_viz\\nlp\\experiments\\exp-001_Prepare_csv_for_EDA\\scripts')

# %%
from reader import CSVCorpusReader

# %%
# Создадим объект чтения корпуса
data = CSVCorpusReader('../../../data/interim')

# %%
# Новостные источники
data.categories()
# Out:
# ['gazeta', 'interfax', 'iz', 'meduza', 'ria', 'rt', 'tass']

# %%
# Имеющиеся файлы в корпусе
data.fileids()
# Out:
# ['gazeta/gazeta.csv',
#  'interfax/interfax.csv',
#  'iz/iz.csv',
#  'meduza/meduza.csv',
#  'ria/ria.csv',
#  'rt/rt.csv',
#  'tass/tass.csv']

# %%
# Проверим размер нашего сета, который будем обрабатывать
list(data.sizes(None, 'meduza'))
# Out:
# [(FileSystemPathPointer('C:\\projects\\datascience\\proj_news_viz\\nlp\\data\\interim\\meduza\\meduza.csv'),
#   304624500)]

# %% [markdown]
# ## Общий предварительный анализ

# %%
# Предварительный анализ всех файлов из каталога новостного источника
data.describe(None, 'meduza')
# Out:
# {'Количество файлов': 1,
#  'Количество источников новостей': 1,
#  'Количество обработанных новостей': 71807,
#  'Количество предложений': 916717,
#  'Количество слов': 27118968,
#  'Количество токенов (словарь)': 502263,
#  'Коэффициент лексического разнообразия (lexical diversity)': 53.99356114227009,
#  'Среднее количество новостей по отношению к файлам': 71807.0,
#  'Среднее количество предложений в новостях': 12.766401604300416,
#  'Начальная дата в обработке': '2014-09-12 09:04:00',
#  'Конечная дата в обработке': '2019-08-07 05:28:00',
#  'Количество повторяющихся новостей': 1382,
#  'Количество пустых новостных элементов': 1372,
#  'Время обработки в секундах': 272.0839991569519}

# %% [markdown]
# ## EDA

# %%
list_data = list(data.docs(None, 'meduza'))

# %%
# Так выглядет датасет
list_data[:5]
# Out:
# [OrderedDict([('date', '2019-08-06 14:15:00'),
#               ('url',
#                'https://meduza.io/feature/2019/08/06/matros-razgovarival-v-kazarme-po-videosvyazi'),
#               ('edition', '-'),
#               ('topics', ''),
#               ('authors', ''),
#               ('title', 'Матрос разговаривал в\xa0казарме по\xa0видеосвязи'),
#               ('text',
#                'С\xa0марта 2019 года российским военным запрещено пользоваться смартфонами и\xa0публиковать в\xa0интернете фотографии со\xa0службы. Соответствующие поправки к\xa0закону «О\xa0статусе военнослужащих» правительство подготовило в\xa0сентябре 2018 года, а\xa0Госдума и\xa0Совет Федерации одобрили их\xa0в\xa0феврале 2019-го. В\xa0марте закон подписал президент России Владимир Путин, и\xa017\xa0марта онnвступилnв\xa0силу. Российских военных сразу\xa0же начали наказывать за\xa0найденные у\xa0них смартфоны и\xa0фото в\xa0социальных сетях: обычно им\xa0дают от\xa0пяти до\xa015 суток ареста, выяснила «Медуза», изучив решения военных судов.nВ\xa0пояснительной записке к\xa0поправкам правительствоnсвязывалоnих\xa0необходимость с\xa0военной операцией в\xa0Сирии: еще до\xa0того, как Россия в\xa0сентябре 2015 года официально объявила о\xa0ее\xa0начале, рас
#               ('reposts_ok', '-'),
#               ('reposts_twi', '-'),
#               ('reposts_lj', '-'),
#               ('reposts_tg', '-'),
#               ('likes', '-'),
#               ('views', '-'),
#               ('comm_count', '-'),
#               (None, [''])]),
#  OrderedDict([('date', '2019-08-06 14:20:00'),
#               ('url',
#                'https://meduza.io/news/2019/08/06/umerla-feshn-direktor-tsuma-alla-verber'),
#               ('edition', '-'),
#               ('topics', ''),
#               ('authors', ''),
#               ('title', 'Умерла фэшн-директор ЦУМа Алла Вербер'),
#               ('text',
#                'Умерла фэшн-директор московского ЦУМа, вице-президент ювелирной компании Mercury Алла Вербер. Эту информацию изданию Hello подтвердили в\xa0пресс-службе ЦУМа.nДруг Вербер, журналист Олег Шаранnнаписалnв\xa0фейсбуке, что Вербер умерла на\xa0курорте в\xa0Италии; причиной смерти стал инфаркт. Издание Super.runутверждаетn, что его спровоцировал анафилактический шок после ужина с\xa0блюдами из\xa0морепродуктов.nАлле Вербер был 61 год.nАлла Вербер родилась в\xa0Ленинграде. В\xa018 лет вместе с\xa0семьей уехала из\xa0СССР. Жила в\xa0Италии, США и\xa0Канаде, там\xa0же начала работу в\xa0фэшн-бизнесе. В\xa01989 году Вербер вернулась в\xa0СССР, а\xa0последующие годы\xa0стала одной из\xa0первых, кто привез в\xa0Россию западные модные бренды. В\xa01995 году Вербер начала сотрудничать с\xa0компанией Mercury, которая сейчасnявляетсяnединственным владельцем московского ЦУМа. Вербер была фэшн-директором универмага с\xa02004 года.'),
#               ('reposts_fb', '-'),
#               ('reposts_vk', '-'),
#               ('reposts_ok', '-'),
#               ('reposts_twi', '-'),
#               ('reposts_lj', '-'),
#               ('reposts_tg', '-'),
#               ('likes', '-'),
#               ('views', '-'),
#               ('comm_count', '-'),
#               (None, [''])]),
#  OrderedDict([('date', '2019-08-06 14:10:00'),
#               ('url',
#                'https://meduza.io/feature/2019/08/06/sama-eta-mysl-kazalas-duratskoy-roboty-pchely-ubivayut-lyudey'),
#               ('edition', '-'),
#               ('topics', ''),
#               ('authors', ''),
#               ('title',
#                'Сама эта мысль казалась дурацкой: роботы-пчелы убивают людей?'),
#               ('text',
#                '13\xa0августа в\xa0издательстве «Эксмо» выходит книгаn«Black Mirror. Внутри Черного Зеркала», в\xa0которой описано создание сериала от\xa0Netflix. Ее\xa0авторы\xa0— шоураннер проектаnЧарли Брукер, продюсер Аннабель Джонс и\xa0писатель Джейсон Арнопп. С\xa0разрешения издательства «Медуза» публикует главу о\xa0последнем эпизоде третьего сезона\xa0— «Враг народа», в\xa0котором герои пытаются спасти пользователей соцсетей от\xa0смерти. В\xa0ней всем, кто получил сообщения с\xa0хештегом #СмертьТебе, угрожают дроны-пчелы, проникающие в\xa0мозг. В\xa0этом фрагменте авторы шоу рассказывают, как придумали сюжет и\xa0чуть не\xa0отказались от\xa0него.nАннабель Джонс (исполнительный продюсер, автор книги,\xa0— прим. «Медузы»)n: Фильм построен почти как история о\xa0серийном убийце или традиционный детективный мини-сериал-nхуданитn, где постепенно раскрывается то, что происходит. Для нас это было что-то новенькое. Мир сост
#               ('reposts_vk', '-'),
#               ('reposts_ok', '-'),
#               ('reposts_twi', '-'),
#               ('reposts_lj', '-'),
#               ('reposts_tg', '-'),
#               ('likes', '-'),
#               ('views', '-'),
#               ('comm_count', '-'),
#               (None, [''])]),
#  OrderedDict([('date', '2019-08-06 14:35:00'),
#               ('url',
#                'https://meduza.io/news/2019/08/06/u-zaderzhannyh-na-aktsii-za-svobodnye-vybory-3-avgusta-pytalis-vzlomat-telegram-i-gmail-ranee-ih-telefony-iz-yala-politsiya'),
#               ('edition', '-'),
#               ('topics', ''),
#               ('authors', ''),
#               ('title',
#                'У\xa0задержанных на\xa0акции за\xa0свободные выборы 3\xa0августа пытались взломать Telegram и\xa0Gmail. Ранее их\xa0телефоны изъяла полиция'),
#               ('text',
#                'Некоторые участникиnакции 3\xa0августаn, у\xa0которых полиция при задержании изъяла телефоны, столкнулись с\xa0попытками взломов мессенджера Telegram и\xa0почты Gmail. Об\xa0этом сообщает «Новая газета», не\xa0указывая источник информации.nПолиция изъяла телефоны у\xa0задержанных участников акции в\xa0рамках «nмосковского делаn», возбужденного после другой акции за\xa0свободные выборы, прошедшей 27\xa0июля.nДемонстрантов допрашивали как свидетелей, а\xa0их\xa0телефоны приобщили к\xa0материалам дела, несмотря на\xa0то, что задержанные 3\xa0августа не\xa0участвовали в\xa0мероприятии 27\xa0июляnС\xa0середины июля незарегистрированные кандидаты в\xa0Мосгордуму проводят в\xa0Москве акции за\xa0свободные выборы. Полиция и\xa0Росгвардия жестко разгоняют участников несогласованных мероприятий\xa0— на\xa0каждой из\xa0двух последних акций были задержаны более тысячи человек. 10\xa0августа в\xa0Москве на\xa0проспекте Сахарова пройдет согласованный митинг за\xa0свободные выборы.'),
#               ('reposts_fb', '-'),
#               ('reposts_vk', '-'),
#               ('reposts_ok', '-'),
#               ('reposts_twi', '-'),
#               ('reposts_lj', '-'),
#               ('reposts_tg', '-'),
#               ('likes', '-'),
#               ('views', '-'),
#               ('comm_count', '-'),
#               (None, [''])]),
#  OrderedDict([('date', '2019-08-06 15:00:00'),
#               ('url',
#                'https://meduza.io/feature/2019/08/06/pochemu-vash-tovar-ploho-prodaetsya-v-internete'),
#               ('edition', '-'),
#               ('topics', ''),
#               ('authors', ''),
#               ('title', 'Почему ваш товар плохо продается в\xa0интернете?'),
#               ('text',
#                'Интернет-покупатели становятся все капризнее, а\xa0конкуренция среди поставщиков\xa0— все острее. Важно не\xa0только собрать правильный ассортимент, подобрать упаковку, сделать качественные фото, но\xa0и\xa0организовать своевременную доставку и\xa0разобраться с\xa0системами аналитики. Вместе с\xa0компаниейnBuy Liken, которая занимается продвижением товаров на\xa0интернет-площадках, рассказываем, что стоит сделать ради увеличения продаж и\xa0привлечения новых покупателей.nЧтобы товар хорошо продавался, нужно определить эффективные рынки сбыта. Это может быть небольшой физический магазин или федеральная сеть, собственный онлайн-магазин или инстаграм-аккаунт. Чем больше разных площадок вы\xa0задействуете, тем больше покупателей сможете охватить.nРади увеличения своей представленности на\xa0рынке многие бренды продают товары на\xa0маркетплейсах. Их\xa0много, и\xa0у\xa0каждого своя специфика. Например, Wildberries делает ставку на\xa0одежду, обувь и\xa0аксессуары, но\xa0теперь продает косметику, спортивные товары, игрушки. Ozon начинал с\xa0продажи книг, но\xa0со\xa0временем так расширил ассортимент, что выделить лидирующие категории уже непросто. Есть и\xa0другие нюансы: например, Ozon продает крупногабаритные товары\xa0— бытовую технику, велосипеды, детские санки. А\xa0у\xa0Wildberries есть ограничения по\xa0размеру, и\xa0он\xa0не\xa0хранит на\xa0своих складах крупногабаритные товары.nУ\xa0Wildberries есть конкурент\xa0— Lamoda, крупный интернет-магазин, который торгует в\xa0основном одеждой и\xa0обувью. Другой маркетплейс, KupiVip, специализируется на\xa0продаже брендовой одежды прошлых сезонов с\xa0большими скидками. Еще есть универсальный маркетплейс Goods.ru, но\xa0он\xa0активнее работает с\xa0производителями электроники, кроме того, его география ограничена Москвой и\xa0Московской областью, зато он\xa0доставляет заказы уже на\xa0следующий день.nОдин из\xa0новых маркетплейсов\xa0— «Беру», совместный проект «Яндекса» и\xa0Сбербанка.nПо\xa0планамnони должны открыть пункты выдачи заказов в\xa0тысячах отделений банка по\xa0всей стране.nЛогичнее всего искать своего покупателя на\xa0тех площадках, где уже продается товар, подобный вашему. Когда подыскали новый магазин или сайт, задайтесь вопросом, насколько органично будет смотреться здесь ваш ассортимент. Например, если вы\xa0продаете посуду, сначала рассмотрите магазины, которые активно торгуют кухонной утварью и\xa0другими товарами для дома. Такая площадка умеет эффективно продвигать подобный товар. Там будет проще протестировать ассортимент, определить более ходовые позиции, поиграть с\xa0ценообразованием, поучаствовать в\xa0промокампаниях и\xa0сформировать собственную политику относительно скидочных акций.nОднако не\xa0стоит совсем отказываться от\xa0площадок, которые на\xa0первый взгляд кажутся нецелевыми. После первой, пробной поставки может оказаться, что аудитория «неподходящего» магазина вполне неплохо реагирует на\xa0ваш товар.nДемонстрируйте свой товар так, чтобы покупатель понял, какую выгоду получит благодаря покупке. Для этого вы\xa0сами должны четко понимать преимущества своего товара и\xa0отражать все его качества в\xa0карточке товара на\xa0сайте. Заголовок должен быть емким и\xa0отражать суть, а\xa0описание\xa0— давать одновременно подробную и\xa0конкретную информацию: из\xa0чего состоит товар, как используется, кому будет полезен. Сухим перечислением ограничиваться не\xa0стоит\xa0— текст должен быть «продающим». Просто «радиоуправляемая машинка» должна стать машинкой, которую родители захотят подарить своему ребенку. Возможно, стоит написать, что она долговечная, современная и\xa0безопасная. А, например, чай «Ананасовая феерия» может привлечь больше покупателей, чем просто «Чай со\xa0вкусом ананаса».nПо\xa0подсчетамnBuy Liken, только около 10% покупателей выбирают товар по\xa0описанию, остальные «покупают глазами». Поэтому чтобы товар лучше продавался, не\xa0стоит экономить на\xa0качестве фото. Поскольку покупатель не\xa0может потрогать предмет, е ...
#               ('reposts_fb', '-'),
#               ('reposts_vk', '-'),
#               ('reposts_ok', '-'),
#               ('reposts_twi', '-'),
#               ('reposts_lj', '-'),
#               ('reposts_tg', '-'),
#               ('likes', '-'),
#               ('views', '-'),
#               ('comm_count', '-'),
#               (None, [''])])]

# %%
# Можно в пандас загрузить и посмотреть

# %%
import pandas as pd

# %%
df = pd.DataFrame(list_data)

# %%
df.head()
# Out:
#                   date                                                url  \
# 0  2019-08-06 14:15:00  https://meduza.io/feature/2019/08/06/matros-ra...
# 1  2019-08-06 14:20:00  https://meduza.io/news/2019/08/06/umerla-feshn...
# 2  2019-08-06 14:10:00  https://meduza.io/feature/2019/08/06/sama-eta-...
# 3  2019-08-06 14:35:00  https://meduza.io/news/2019/08/06/u-zaderzhann...
# 4  2019-08-06 15:00:00  https://meduza.io/feature/2019/08/06/pochemu-v...
#
#   edition topics authors                                              title  \
# 0       -                       Матрос разговаривал в казарме по видеосвязи
# 1       -                             Умерла фэшн-директор ЦУМа Алла Вербер
# 2       -                 Сама эта мысль казалась дурацкой: роботы-пчелы...
# 3       -                 У задержанных на акции за свободные выборы 3 а...
# 4       -                     Почему ваш товар плохо продается в интернете?
#
#                                                 text reposts_fb reposts_vk  \
# 0  С марта 2019 года российским военным запрещено...          -          -
# 1  Умерла фэшн-директор московского ЦУМа, вице-пр...          -          -
# 2  13 августа в издательстве «Эксмо» выходит книг...          -          -
# 3  Некоторые участникиnакции 3 августаn, у которы...          -          -
# 4  Интернет-покупатели становятся все капризнее, ...          -          -
#
#   reposts_ok reposts_twi reposts_lj reposts_tg likes views comm_count NaN
# 0          -           -          -          -     -     -          -  []
# 1          -           -          -          -     -     -          -  []
# 2          -           -          -          -     -     -          -  []
# 3          -           -          -          -     -     -          -  []
# 4          -           -          -          -     -     -          -  []

# %% [markdown]
# ### Обработка словаря

# %%
# Соберем токены
tokens = data.gettokens

# %%
punctuation = list(punctuation)

# %%
punctuation += ['«','»','—', 'n','»,','».', '–', '...']

# %%
garbage_words = ['nранее', 'nв', 'nпо', 'nтакже','u','n—', 'nn']

# %%
tokens = {item:tokens[item] for item in tokens if item not in punctuation}

# %%
tokens = {item:tokens[item] for item in tokens if item not in garbage_words}

# %%
stopwords_01 = open('../../../data/another/stopwords.txt', 'r', encoding='UTF-8')
stopwords_01 = stopwords_01.read().split('\n')
stopwords_02 = open('../../../data/another/stopwords_02.txt', 'r', encoding='UTF-8')
stopwords_02 = stopwords_02.read().split('\n')

# %%
stopwords = stopwords_01 + stopwords_02

# %%
tokens_without_stopwords = {item:tokens[item] for item in tokens if item not in stopwords}

# %% [markdown]
# ### Аналитика по словам

# %% [markdown]
# #### Топ-20 слов без удаления стоп-слов

# %%
Counter(tokens).most_common(20)
# Out:
# [('в', 941958),
#  ('и', 547653),
#  ('на', 380631),
#  ('что', 282945),
#  ('не', 281658),
#  ('с', 246796),
#  ('по', 194597),
#  ('о', 115383),
#  ('из', 115310),
#  ('это', 108190),
#  ('как', 104513),
#  ('а', 103412),
#  ('он', 95932),
#  ('к', 95481),
#  ('за', 90187),
#  ('его', 86492),
#  ('но', 84367),
#  ('года', 79526),
#  ('я', 76064),
#  ('у', 74929)]

# %%
x = dict(Counter(tokens).most_common(20)).keys()
y = dict(Counter(tokens).most_common(20)).values()

fig, ax = plt.subplots()

ax.bar(x, y)
ax.set_title('TOP-20 слов без удаления стопслов')
ax.set_ylabel('Частота')
ax.set_xlabel('Слова')

ax.set_facecolor('seashell')
fig.set_facecolor('floralwhite')
fig.set_figwidth(12)    #  ширина Figure
fig.set_figheight(6)    #  высота Figure


plt.show()

# %% [markdown]
# #### Топ-20 слов после удаления стоп-слов

# %%
Counter(tokens_without_stopwords).most_common(20)
# Out:
# [('россии', 51788),
#  ('рф', 24051),
#  ('сша', 23942),
#  ('словам', 22038),
#  ('рублей', 20688),
#  ('заявил', 20194),
#  ('из-за', 18196),
#  ('2015', 16385),
#  ('2016', 16334),
#  ('данным', 16152),
#  ('компании', 15971),
#  ('людей', 15044),
#  ('власти', 14472),
#  ('например', 14218),
#  ('президента', 14177),
#  ('числе', 13784),
#  ('2014', 13078),
#  ('“', 12941),
#  ('„', 12602),
#  ('человека', 12368)]

# %%
x = dict(Counter(tokens_without_stopwords).most_common(20)).keys()
y = dict(Counter(tokens_without_stopwords).most_common(20)).values()

fig, ax = plt.subplots()

ax.bar(x, y)
ax.set_title('TOP-20 слов без удаления стопслов')
ax.set_ylabel('Частота')
ax.set_xlabel('Слова')

ax.set_facecolor('seashell')
fig.set_facecolor('floralwhite')
fig.set_figwidth(22)    #  ширина Figure
fig.set_figheight(6)    #  высота Figure


plt.show()

# %% [markdown]
# ## Рубрики в разрезе новостей

# %% [markdown]
# ### Количество рубрик

# %%
list_topics = list(data.listcolumns(None, 'meduza', 'topics'))

# %%
len(set(list_topics))
# Out:
# 1

# %% [markdown]
# ### Рубрики в разрезе количества новостей

# %%
Counter(list_topics).most_common(34)
# Out:
# [('', 71807)]

# %% [markdown]
# ## Распределение количества новостей по месяцам

# %% [markdown]
# ### Удаление дубликатов

# %%
# Новый словарь, ключами которого будут новости, таким образом будет создан
# новый словарь, без дубликатов
news_by_dict = {i['text']: i for i in list_data}
new_items = list(news_by_dict.values())

# %%
# Проверь, что количество дубликатов совпало с тем, что были в предварительном анализе
# все верно
len(list_data) - len(new_items)
# Out:
# 1382

# %% [markdown]
# ### Получение распределения

# %%
def getMonthDate(date):
  """
  Возвращает дату в формате ММ-ГГГГ
  """
  date = datetime.datetime.strptime(date, "%Y-%m-%d %H:%M:%S")
  return '-'.join(['0' + str(date.month) if date.month<10 else str(date.month), str(date.year)])

# %%
# Подсчет количества новостей в разрезе месяца и года
list_dates = [getMonthDate(x['date']) for x in new_items]

# %%
month_year = Counter(list_dates)

# %%
len(month_year)
# Out:
# 60

# %%
month_year.most_common(20)
# Out:
# [('04-2016', 1414),
#  ('03-2016', 1398),
#  ('07-2016', 1392),
#  ('03-2017', 1388),
#  ('08-2016', 1377),
#  ('11-2016', 1370),
#  ('04-2017', 1368),
#  ('12-2015', 1362),
#  ('05-2016', 1350),
#  ('07-2019', 1330),
#  ('05-2017', 1324),
#  ('11-2015', 1323),
#  ('06-2017', 1314),
#  ('10-2016', 1312),
#  ('02-2016', 1306),
#  ('12-2016', 1304),
#  ('08-2017', 1295),
#  ('10-2017', 1290),
#  ('09-2016', 1285),
#  ('08-2018', 1281)]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
plt.bar(x = month_year.keys(),
        height = month_year.values())
plt.xticks(rotation='vertical')
ax.set_facecolor('seashell')
fig.set_facecolor('floralwhite')

ax.set_title('Количество новостей по месяцам')
ax.set_ylabel('Количество')
ax.set_xlabel('Дата')
plt.show()
