# %%
import numpy as np
import pandas as pd
import os

import re
from ast import literal_eval
from datetime import datetime as time
from ast import literal_eval
from sklearn.model_selection import train_test_split

import artm
from gensim.models import Phrases
from gensim.models.phrases import Phraser

import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls -lah data/*.csv.bz2
# Out:
# -rw-rw-r-- 1 vtrokhymenko vtrokhymenko 33M Feb 13 11:48 data/Byvsij_SSSR.csv.bz2
# -rw-rw-r-- 1 vtrokhymenko vtrokhymenko 75M Feb 13 11:35 data/Ekonomika.csv.bz2
# -rw-rw-r-- 1 vtrokhymenko vtrokhymenko 51M Feb 13 11:45 data/Mir.csv.bz2

# %%
name_dataset = 'Byvsij_SSSR'

# %% [markdown]
# ### load data

# %%
# %%time
df = pd.read_csv(f'data/{name_dataset}.csv.bz2')
print(df.shape)
# Out:
# (45046, 6)
# CPU times: user 10.6 s, sys: 1.03 s, total: 11.6 s
# Wall time: 9.72 s

# %%
df.head()
# Out:
#                   date        topic  \
# 0  2008-02-11 09:23:00  "Экономика"
# 1  2008-02-11 12:55:00  "Экономика"
# 2  2008-02-11 18:27:00   "В России"
# 3  2008-02-11 23:05:00   "В России"
# 4  2008-02-13 10:20:00   "В России"
#
#                                                 text      predict  \
# 0   - Отношения между Москвой и Киевом в газовой ...  Бывший СССР
# 1   - Премьер-министр Украины Юлия Тимошенко заяв...  Бывший СССР
# 2   - Ключевым вопросом визита президента Украины...  Бывший СССР
# 3   - Парламентское большинство не намерено разбл...  Бывший СССР
# 4   - Известный грузинский бизнесмен Бадри Патарк...  Бывший СССР
#
#                                             text_new  \
# 0  отношения между москвой и киевом в газовой сфе...
# 1  премьерминистр украины юлия_тимошенко заявляет...
# 2  ключевым вопросом визита президента украины ви...
# 3  парламентское большинство не намерено разблоки...
# 4  известный грузинский бизнесмен бадри_патаркаци...
#
#                                      lemmatized_text
# 0  ['москва', 'киев', 'газовый', 'сфера', 'входит...
# 1  ['премьерминистр', 'украина', 'юлия_тимошенко'...
# 2  ['ключевой', 'вопрос', 'визит', 'украина', 'ви...
# 3  ['парламентский', 'большинство', 'намерить', '...
# 4  ['известный', 'грузинский', 'бизнесмен', 'бадр...

# %% [markdown]
# * parse data

# %%
df['year'] = df['date'].apply(lambda x: int(x.split(' ')[0].split('-')[0]))
df['month'] = df['date'].apply(lambda x: int(x.split(' ')[0].split('-')[1]))
df.head()
# Out:
#                   date        topic  \
# 0  2008-02-11 09:23:00  "Экономика"
# 1  2008-02-11 12:55:00  "Экономика"
# 2  2008-02-11 18:27:00   "В России"
# 3  2008-02-11 23:05:00   "В России"
# 4  2008-02-13 10:20:00   "В России"
#
#                                                 text      predict  \
# 0   - Отношения между Москвой и Киевом в газовой ...  Бывший СССР
# 1   - Премьер-министр Украины Юлия Тимошенко заяв...  Бывший СССР
# 2   - Ключевым вопросом визита президента Украины...  Бывший СССР
# 3   - Парламентское большинство не намерено разбл...  Бывший СССР
# 4   - Известный грузинский бизнесмен Бадри Патарк...  Бывший СССР
#
#                                             text_new  \
# 0  отношения между москвой и киевом в газовой сфе...
# 1  премьерминистр украины юлия_тимошенко заявляет...
# 2  ключевым вопросом визита президента украины ви...
# 3  парламентское большинство не намерено разблоки...
# 4  известный грузинский бизнесмен бадри_патаркаци...
#
#                                      lemmatized_text  year  month
# 0  ['москва', 'киев', 'газовый', 'сфера', 'входит...  2008      2
# 1  ['премьерминистр', 'украина', 'юлия_тимошенко'...  2008      2
# 2  ['ключевой', 'вопрос', 'визит', 'украина', 'ви...  2008      2
# 3  ['парламентский', 'большинство', 'намерить', '...  2008      2
# 4  ['известный', 'грузинский', 'бизнесмен', 'бадр...  2008      2

# %%
df.year.value_counts()
# Out:
# 2014    7599
# 2015    7548
# 2008    4996
# 2009    4578
# 2016    4219
# 2010    3777
# 2017    3287
# 2018    3049
# 2011    2144
# 2013    1908
# 2012    1807
# 2019     134
# Name: year, dtype: int64

# %%
df.month.value_counts()
# Out:
# 4     4607
# 2     4177
# 5     4076
# 8     3980
# 7     3808
# 3     3802
# 6     3703
# 10    3579
# 9     3389
# 1     3376
# 12    3375
# 11    3174
# Name: month, dtype: int64

# %%
df.lemmatized_text = df.lemmatized_text.apply(lambda x: literal_eval(x))

# %% [markdown]
# ### preprocess if text with lemma

# %% [markdown]
# * add docID

# %%
df['docID'] = list(range(df.shape[0]))

# %%
df = df[['docID','year','month','lemmatized_text']]
df.head(2)
# Out:
#    docID  year  month                                    lemmatized_text
# 0      0  2008      2  [москва, киев, газовый, сфера, входить, зона, ...
# 1      1  2008      2  [премьерминистр, украина, юлия_тимошенко, заяв...

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (45046, 4)
# docID              0
# year               0
# month              0
# lemmatized_text    0
# dtype: int64

# %%
df.year.min(),df.year.max()
# Out:
# (2008, 2019)

# %% [markdown]
# ### preprocess if text full

# %% [markdown]
# * get dates

# %%
# %%time

df['date_raw'] = df['url'].apply(re.compile('(\d{4})/(\d{2})/(\d{2})').findall)

df['year'] = df['date_raw'].apply(lambda x: int(x[0][0]))
df['month'] = df['date_raw'].apply(lambda x: int(x[0][1]))

# %% [markdown]
# * clean text

# %%
import preprocessing_tools as pr

# %%
# %%time
df.text = df.text.apply(pr.clean_text)

# %%
df.head(2)

# %% [markdown]
# * cleanedNames

# %%
from cleanedNames import KeyProc
cn = KeyProc()

# %%
# %%time
df.text = df.text.apply(cn.replaceKeywords)

# %% [markdown]
# * lemmatization

# %%
# %%time
df['lemmatized_text'] = df.text.apply(pr.lemmatization)

# %% [markdown]
# * add docID

# %%
df['docID'] = list(range(df.shape[0]))

# %%
df = df[['docID','year','month','lemmatized_text']]
df.head(2)

# %%
print(df.shape)
df.isnull().sum()

# %%
df.year.min()

# %% [markdown]
# ## model

# %% [markdown]
# * prepare

# %%
# %%time

vwpath = f'data/vwpath/{name_dataset}_input_bigartm.vw'

with open(vwpath, 'w') as fp:
    for text, did in df[['lemmatized_text', 'docID']].values:
        fp.write('{} | {}\n'.format(did, ' '.join(text)))
# Out:
# CPU times: user 408 ms, sys: 109 ms, total: 517 ms
# Wall time: 442 ms

# %%
id_date = df[['docID', 'year', 'month']].copy()

# %% [markdown]
# * collect batchs and collect the dictionary

# %%
# %%time

batches_path = f'data/batches/{name_dataset}'

if not os.path.exists(batches_path):
    print('create folder...\n')
    os.makedirs(batches_path)
    
batch_vectorizer = artm.BatchVectorizer(data_path=vwpath,
                                        data_format='vowpal_wabbit',
                                        target_folder=batches_path)

print(batch_vectorizer)
# Out:
# artm.BatchVectorizer(data_path="data/batches/Byvsij_SSSR", num_batches=46)
# CPU times: user 14.6 s, sys: 249 ms, total: 14.8 s
# Wall time: 2.71 s

# %%
dictionary = artm.Dictionary()
dictionary.gather(data_path=batches_path)

# %%
dictionary.filter(min_tf=10, max_df_rate=0.1) #int(4.5e5)
# Out:
# artm.Dictionary(name=5a1c5ad5-86e9-43c4-8287-e5736d69b48f, num_entries=18049)

# %%
dictionary.save_text(f'data/dicts/dict_{name_dataset}.txt')

# %% [markdown]
# ## pick up amount topics

# %%
# %%time
model_list = []
step, perplexity, sTheta, sPhi = [], [], [], []

start = 10
end = 25
stepp = 1

for i in range(start,end+1,stepp):
    print(f'#topic {i}.........')
    step.append(i)
    date_start = time.now()
    
    num_topics = i
    model = artm.ARTM(num_topics=num_topics, dictionary=dictionary)
    
    # scores
    model.scores.add(artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary))
    model.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore'))
    model.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore'))
    
    # 1st regularizer
    model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='SparsePhi', tau=-1.0)) #-0.1
    model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=5)
    
    # 2st regularizer
    model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.5))
    model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)
    
    # 3st regularizer
    model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=1.5e+5))
    model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)
    
    model_list.append(model)
    
    sparsityTheta = model.score_tracker['SparsityThetaScore'].last_value
    sTheta.append(sparsityTheta)
    sparsityPhi = model.score_tracker['SparsityPhiScore'].last_value
    sPhi.append(sparsityPhi)
    perpl = model.score_tracker['PerplexityScore'].last_value
    perplexity.append(perpl)
    
    print(f'\tSparsityThetaScore: {sparsityTheta}')
    print(f'\tSparsityPhiScore: {sparsityPhi}')
    print(f'\tPerplexityScore: {perpl}')
    
    print('\ttime:',time.now()-date_start)
# Out:
# #topic 10.........
# 	SparsityThetaScore: 0.5643187165260315
# 	SparsityPhiScore: 0.783882737159729
# 	PerplexityScore: 2351.791015625
# 	time: 0:00:20.646432
# #topic 11.........
# 	SparsityThetaScore: 0.5848264098167419
# 	SparsityPhiScore: 0.7971582412719727
# 	PerplexityScore: 2298.64453125
# 	time: 0:00:45.283527
# #topic 12.........
# 	SparsityThetaScore: 0.5974799990653992
# 	SparsityPhiScore: 0.8114854097366333
# 	PerplexityScore: 2246.038818359375
# 	time: 0:00:58.929243
# #topic 13.........
# 	SparsityThetaScore: 0.6117029190063477
# 	SparsityPhiScore: 0.8236169219017029
# 	PerplexityScore: 2198.408447265625
# 	time: 0:00:59.058416
# #topic 14.........
# 	SparsityThetaScore: 0.6264421939849854
# 	SparsityPhiScore: 0.8327528834342957
# 	PerplexityScore: 2165.554931640625
# 	time: 0:01:00.477918
# #topic 15.........
# 	SparsityThetaScore: 0.6404001712799072
# 	SparsityPhiScore: 0.8420411348342896
# 	PerplexityScore: 2125.78955078125
# 	time: 0:00:59.193875
# #topic 16.........
# 	SparsityThetaScore: 0.6518183946609497
# 	SparsityPhiScore: 0.8492506742477417
# 	PerplexityScore: 2097.781982421875
# 	time: 0:01:08.016661
# #topic 17.........
# 	SparsityThetaScore: 0.6627630591392517
# 	SparsityPhiScore: 0.8564756512641907
# 	PerplexityScore: 2065.01025390625
# 	time: 0:01:03.930812
# #topic 18.........
# 	SparsityThetaScore: 0.6724188327789307
# 	SparsityPhiScore: 0.8625193238258362
# 	PerplexityScore: 2044.0321044921875
# 	time: 0:01:08.136682
# #topic 19.........
# 	SparsityThetaScore: 0.6817978024482727
# 	SparsityPhiScore: 0.8690494298934937
# 	PerplexityScore: 2014.3359375
# 	time: 0:01:10.583729
# #topic 20.........
# 	SparsityThetaScore: 0.6896650195121765
# 	SparsityPhiScore: 0.8750097155570984
# 	PerplexityScore: 1986.9915771484375
# 	time: 0:01:09.692253
# #topic 21.........
# 	SparsityThetaScore: 0.6961825489997864
# 	SparsityPhiScore: 0.8796688318252563
# 	PerplexityScore: 1958.109375
# 	time: 0:01:12.738635
# #topic 22.........
# 	SparsityThetaScore: 0.7019107937812805
# 	SparsityPhiScore: 0.8847078084945679
# 	PerplexityScore: 1921.8037109375
# 	time: 0:01:17.537686
# #topic 23.........
# 	SparsityThetaScore: 0.7073204517364502
# 	SparsityPhiScore: 0.8893109560012817
# 	PerplexityScore: 1898.5699462890625
# 	time: 0:01:21.510051
# #topic 24.........
# 	SparsityThetaScore: 0.71381014585495
# 	SparsityPhiScore: 0.8939230442047119
# 	PerplexityScore: 1871.1136474609375
# 	time: 0:01:23.330914
# #topic 25.........
# 	SparsityThetaScore: 0.719875693321228
# 	SparsityPhiScore: 0.8974546790122986
# 	PerplexityScore: 1855.7406005859375
# 	time: 0:01:24.732028
# CPU times: user 1h 36min 32s, sys: 10min 28s, total: 1h 47min
# Wall time: 17min 23s

# %%
#model_list

# %%
plt.plot(step, sPhi, color='k',linewidth=3, marker='x')
ax = plt.gca()
ax.set_xticks(step)
plt.grid()
plt.title('SparsityPhiScore')
# Out:
# Text(0.5, 1.0, 'SparsityPhiScore')

# %%
index_sphi = []
[index_sphi.append(float(str(i)[:3]) ) for i in sPhi]
    
index_sphi = list(set(index_sphi))
index_sphi.sort()
index_sphi
# Out:
# [0.7, 0.8]

# %%
d_sphi = {}

for j in range(len(index_sphi)):
    k=0
    for i in sPhi:
        if j==range(len(index_sphi))[-1]:
            if (i>=index_sphi[j]):
                k+=1
        else:
            if (i>=index_sphi[j]) & (i<index_sphi[j+1]):
                k+=1
    d_sphi[index_sphi[j]]=k

d_sphi
# Out:
# {0.7: 2, 0.8: 14}

# %%
plt.plot(step, sTheta, color='g',linewidth=3, marker='x')
ax = plt.gca()
ax.set_xticks(step)
plt.grid()

plt.title('SparsityThetaScore')
# Out:
# Text(0.5, 1.0, 'SparsityThetaScore')

# %%
index_theta = []
[index_theta.append(float(str(i)[:3])) for i in sTheta]
    
index_theta = list(set(index_theta))
index_theta.sort()
index_theta
# Out:
# [0.5, 0.6, 0.7]

# %%
d_stheta = {}

for j in range(len(index_theta)):
    k=0
    for i in sTheta:
        if j==range(len(index_theta))[-1]:
            if (i>=index_theta[j]):
                k+=1
        else:
            if (i>=index_theta[j]) & (i<index_theta[j+1]):
                k+=1
    d_stheta[index_theta[j]]=k

d_stheta
# Out:
# {0.5: 3, 0.6: 9, 0.7: 4}

# %%
plt.plot(step, perplexity, color='b',linewidth=3, marker='x')
ax = plt.gca()
ax.set_xticks(step)
plt.grid()
plt.title('PerplexityScore')
# Out:
# Text(0.5, 1.0, 'PerplexityScore')

# %%
perplexity
# Out:
# [2351.791015625,
#  2298.64453125,
#  2246.038818359375,
#  2198.408447265625,
#  2165.554931640625,
#  2125.78955078125,
#  2097.781982421875,
#  2065.01025390625,
#  2044.0321044921875,
#  2014.3359375,
#  1986.9915771484375,
#  1958.109375,
#  1921.8037109375,
#  1898.5699462890625,
#  1871.1136474609375,
#  1855.7406005859375]

# %% [markdown]
# ### select the best model

# %%
print(f'd_sphi:   {d_sphi}')
print(f'd_stheta: {d_stheta}')
# Out:
# d_sphi:   {0.7: 2, 0.8: 14}
# d_stheta: {0.5: 3, 0.6: 9, 0.7: 4}

# %%
select_topics = 22 # u should choose number of topic

best_model = model_list[select_topics-start]
print(best_model.num_topics)
# Out:
# 22

# %% [markdown]
# ---

# %%
'''
select_topics = 20

num_topics = select_topics
model = artm.ARTM(num_topics=num_topics, dictionary=dictionary, show_progress_bars=True)

# scores
model.scores.add(artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary))
model.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore'))
model.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore'))

# 1st regularizer
model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='SparsePhi', tau=-1.0)) #-0.1
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=5)

# 2st regularizer
model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.5))
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

# 3st regularizer
model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=1.5e+5))
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

sparsityTheta = model.score_tracker['SparsityThetaScore'].last_value
sparsityPhi = model.score_tracker['SparsityPhiScore'].last_value
perpl = model.score_tracker['PerplexityScore'].last_value

print(f'\tSparsityThetaScore: {sparsityTheta}')
print(f'\tSparsityPhiScore: {sparsityPhi}')
print(f'\tPerplexityScore: {perpl}')

best_model = model.clone()
print(f'best_model.num_topics:{best_model.num_topics}')
'''

# %% [markdown]
# ---

# %% [markdown]
# ### print top words for each topics

# %%
phi = best_model.get_phi()
phi['word'] = phi.index
#phi.head()

for col in phi.columns:
    if col != 'word':
        print(f"{col}: {phi[[col, 'word']].sort_values(by=col, ascending=False)['word'].values[:10]}")
        #print('\t',phi[[col, 'word']].sort_values(by=col, ascending=False)['word'].values[:10])
# Out:
# topic_0: ['миллион' 'миллиард' 'газа' 'предприятие' 'поставка' 'средство' 'цена'
#  'сумма' 'электроэнергия' 'газ']
# topic_1: ['здание' 'акция' 'участник' 'площадь' 'корреспондент' 'митинг' 'протест'
#  'милиция' 'активист' 'улица']
# topic_2: ['обстрел' 'огонь' 'позиция' 'прекращение' 'пункт' 'линия' 'мм'
#  'направление' 'режим' 'миномёт']
# topic_3: ['оборона' 'крым' 'военнослужащий' 'учение' 'корабль' 'войско' 'база'
#  'нато' 'минобороны' 'граница']
# topic_4: ['киргизия' 'азербайджан' 'бишкек' 'оон' 'узбекистан' 'временной' 'миссия'
#  'снг' 'обсе' 'бакиев']
# topic_5: ['армения' 'абхазия' 'ереван' 'армянский' 'абхазский' 'отставка'
#  'премьерминистр' 'сухуми' 'член' 'пашинянин']
# topic_6: ['белоруссия' 'граница' 'гуманитарный' 'белорусский' 'минск' 'помощь'
#  'пограничный' 'груз' 'пункт' 'мчс']
# topic_7: ['взрыв' 'погибнуть' 'пострадавший' 'погибший' 'больница' 'дом' 'ранение'
#  'пожар' 'пострадать' 'состояние']
# topic_8: ['выбор' 'избирательный' 'кандидат' 'фракция' 'выборы' 'голосование'
#  'парламентский' 'избиратель' 'голос' 'президентский']
# topic_9: ['милиция' 'автомобиль' 'мужчина' 'обнаружить' 'неизвестный' 'летний'
#  'факт' 'управление' 'отдел' 'правоохранительный']
# topic_10: ['прокуратура' 'преступление' 'убийство' 'обвинение' 'расследование'
#  'лицо' 'адвокат' 'арест' 'генеральный' 'следственный']
# topic_11: ['мид' 'встреча' 'переговоры' 'москва' 'заявление' 'иностранный'
#  'молдавия' 'никакой' 'посол' 'пока']
# topic_12: ['сша' 'таджикистан' 'латвия' 'американский' 'помощь' 'афганистан'
#  'посольство' 'визит' 'латвийский' 'школа']
# topic_13: ['соглашение' 'европейский' 'ес' 'политический' 'экономический'
#  'сотрудничество' 'порошенко' 'позиция' 'развитие' 'политика']
# topic_14: ['днр' 'луганский' 'самопровозгласить' 'донбасс' 'обсе' 'лнр' 'ополченец'
#  'донецк' 'восток' 'минский']
# topic_15: ['южный' 'осетия' 'грузинский' 'милиция' 'мвд' 'оружие' 'милиционер'
#  'нападение' 'правоохранительный' 'устройство']
# topic_16: ['эстония' 'литва' 'война' 'эстонский' 'советский' 'русский' 'житель'
#  'большой' 'памятник' 'население']
# topic_17: ['церковь' 'православный' 'независимость' 'акция' 'движение' 'мероприятие'
#  'память' 'патриархат' 'московский' 'шествие']
# topic_18: ['казахстан' 'самолёт' 'аэропорт' 'сбить' 'экипаж' 'крушение' 'боинг'
#  'рейс' 'борт' 'авиакомпания']
# topic_19: ['мвд' 'одесский' 'начальник' 'написать' 'одесса' 'администрация'
#  'внутренний' 'областной' 'сбу' 'управление']
# topic_20: ['грузинский' 'оппозиция' 'тбилиси' 'саакашвили' 'тимошенко'
#  'михаил_саакашвили' 'янукович' 'юлия_тимошенко' 'заявление'
#  'политический']
# topic_21: ['закон' 'верховный' 'документ' 'право' 'совет' 'заседание' 'рада' 'рад'
#  'соответствующий' 'законопроект']

# %% [markdown]
# ### get topics-docs matrix

# %%
theta = best_model.transform_sparse(batch_vectorizer=batch_vectorizer, eps=0.001)
print(f'shape theta: {theta[0].shape}')

plt.figure(figsize=(20, 20))
plt.imshow(theta[0][:, 2000:2500].toarray());
# Out:
# shape theta: (22, 45046)

# %% [markdown]
# ### dense theta matrix

# %%
theta = best_model.transform(batch_vectorizer=batch_vectorizer)
theta = theta.T
theta.head()
# Out:
#        topic_0   topic_1  topic_2   topic_3  topic_4  topic_5  topic_6  \
# 24000      0.0  0.000000      0.0  0.000000      0.0      0.0      0.0
# 24001      0.0  0.000000      0.0  0.000000      0.0      0.0      0.0
# 24002      0.0  0.000000      0.0  0.000000      0.0      0.0      0.0
# 24003      0.0  0.000000      0.0  0.023544      0.0      0.0      0.0
# 24004      0.0  0.012789      0.0  0.113806      0.0      0.0      0.0
#
#         topic_7  topic_8   topic_9    ...     topic_12  topic_13  topic_14  \
# 24000  0.081162      0.0  0.180839    ...          0.0  0.000000  0.499068
# 24001  0.328510      0.0  0.000000    ...          0.0  0.000000  0.345951
# 24002  0.353918      0.0  0.000000    ...          0.0  0.000000  0.312114
# 24003  0.000000      0.0  0.000000    ...          0.0  0.114871  0.142121
# 24004  0.000000      0.0  0.000000    ...          0.0  0.000000  0.124464
#
#        topic_15  topic_16  topic_17  topic_18  topic_19  topic_20  topic_21
# 24000       0.0       0.0       0.0  0.238931       0.0  0.000000  0.000000
# 24001       0.0       0.0       0.0  0.292076       0.0  0.000000  0.033463
# 24002       0.0       0.0       0.0  0.222892       0.0  0.000000  0.000000
# 24003       0.0       0.0       0.0  0.575706       0.0  0.083342  0.021120
# 24004       0.0       0.0       0.0  0.570874       0.0  0.000000  0.104515
#
# [5 rows x 22 columns]

# %% [markdown]
# ## DataViz

# %%
joined = id_date.join(theta)
joined.head()
# Out:
#    docID  year  month   topic_0   topic_1  topic_2  topic_3   topic_4  \
# 0      0  2008      2  0.433729  0.000000      0.0      0.0  0.021411
# 1      1  2008      2  0.595476  0.000000      0.0      0.0  0.000000
# 2      2  2008      2  0.000000  0.000000      0.0      0.0  0.000000
# 3      3  2008      2  0.000000  0.184165      0.0      0.0  0.000000
# 4      4  2008      2  0.000000  0.000000      0.0      0.0  0.000000
#
#     topic_5   topic_6    ...     topic_12  topic_13  topic_14  topic_15  \
# 0  0.002973  0.047639    ...     0.112211  0.193255       0.0  0.000000
# 1  0.000000  0.000000    ...     0.096220  0.000000       0.0  0.000000
# 2  0.000000  0.012282    ...     0.159710  0.619182       0.0  0.000000
# 3  0.000000  0.000000    ...     0.000000  0.144147       0.0  0.000000
# 4  0.000000  0.000000    ...     0.000000  0.096138       0.0  0.049107
#
#    topic_16  topic_17  topic_18  topic_19  topic_20  topic_21
# 0  0.022498  0.000000  0.017039  0.000000  0.026408  0.009009
# 1  0.000000  0.000000  0.000000  0.000000  0.169497  0.000000
# 2  0.000000  0.000000  0.000000  0.098381  0.000000  0.110445
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.059107  0.005616  0.000000  0.008203  0.147644  0.000000
#
# [5 rows x 25 columns]

# %%
topics = ['topic_{}'.format(i) for i in range(select_topics)]
gb = joined.groupby(['year', 'month'])[topics].sum()
print(f'gb.shape: {gb.shape}')
gb.head()
# Out:
# gb.shape: (132, 22)
#               topic_0    topic_1   topic_2    topic_3   topic_4    topic_5  \
# year month
# 2008 2       5.492892   4.233420  0.239153   1.228619  1.698135   8.226724
#      3      24.647877  20.012241  5.943365   7.973896  9.417150  12.124409
#      4      16.787830  14.113843  2.590317  17.170328  6.336670  14.957608
#      5      12.698258  15.239322  2.293649  26.724195  8.796383  16.660278
#      6      12.813042  12.797353  2.967252  15.282129  4.390054  11.520972
#
#               topic_6    topic_7    topic_8    topic_9    ...       topic_12  \
# year month                                                ...
# 2008 2       1.350490   7.043914  12.409540   3.784482    ...       1.266065
#      3       7.639961  22.448563  20.368845  15.406806    ...      14.929720
#      4       7.158126  18.997597  16.650482  24.158848    ...      11.733158
#      5      10.526740  33.159515  27.422283  17.694441    ...      10.183885
#      6       9.300848  39.106216  12.251497  19.977470    ...       9.398525
#
#              topic_13  topic_14   topic_15   topic_16   topic_17   topic_18  \
# year month
# 2008 2       8.906828  0.828020   9.567052   2.850121   2.248303   2.670728
#      3      40.863964  2.201318  20.133432  14.049856  10.525912   9.216154
#      4      44.423355  1.984044  26.212976  16.402122   9.122753   8.577242
#      5      46.049534  2.599358  44.280094  21.133474   9.787307  12.689351
#      6      40.417618  1.042552  30.809513  17.421066   6.189946   7.825546
#
#             topic_19   topic_20   topic_21
# year month
# 2008 2      1.815776  10.011753   3.099423
#      3      6.552118  24.493677  21.409294
#      4      7.677931  17.468025  15.072263
#      5      7.137274  22.501520  15.365364
#      6      7.444602  14.398539  11.930733
#
# [5 rows x 22 columns]

# %% [markdown]
# ### straightforward matrix heatmap

# %%
plt.figure(figsize=(5, 25))
plt.imshow(gb[topics])

# %% [markdown]
# ## pygal

# %%
import pygal
from IPython.display import SVG, HTML

html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

# %%
line_chart = pygal.StackedLine(fill=True, show_dots=False)
line_chart.title = 'Topics'
for topic in topics:
    line_chart.add(topic, gb[topic].values)
    
HTML(html_pygal.format(pygal_render=line_chart.render(is_unicode=True)))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-27630820-f94d-43d7-b336-5c6cf7cfabfa" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-14--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-27630820-f94d-43d7-b336-5c6cf7cfabfa{background-color:rgba(249,249,249,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa path,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa line,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa rect,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .graph{fill:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa text.no_data{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .title{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .legends .legend text{fill:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis .line{stroke:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis text.major{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis.y .guides:hover .guide.line,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .line-graph .axis.x .guides:hover .guide.line,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .stackedline-graph .axis.x .guides:hover .guide.line,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .ci{stroke:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .reactive.active,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .ci .reactive.active{stroke-width:1.5}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .series text{fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .label{fill:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .label{fill:rgba(0,0,0,.87)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .tooltip .value{font-size:1.5em}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .bound{font-size:.5em}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-0,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-1,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-2,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-2 a:visited{stroke:#009688;fill:#009688}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-3,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-4,#chart-27630820-f94d-43d7-b336-5c6cf7cfabfa .color-4 a:visit ...

# %%
line_chart.render_to_file(f"data/visualization/{'-'.join(name_dataset.split('.'))}_pygal.svg")

# %% [markdown]
# ## joypy

# %%
import joypy # !pip install joypy

# %%
print(joined.shape)
joined.head()
# Out:
# (45046, 25)
#    docID  year  month   topic_0   topic_1  topic_2  topic_3   topic_4  \
# 0      0  2008      2  0.433729  0.000000      0.0      0.0  0.021411
# 1      1  2008      2  0.595476  0.000000      0.0      0.0  0.000000
# 2      2  2008      2  0.000000  0.000000      0.0      0.0  0.000000
# 3      3  2008      2  0.000000  0.184165      0.0      0.0  0.000000
# 4      4  2008      2  0.000000  0.000000      0.0      0.0  0.000000
#
#     topic_5   topic_6    ...     topic_12  topic_13  topic_14  topic_15  \
# 0  0.002973  0.047639    ...     0.112211  0.193255       0.0  0.000000
# 1  0.000000  0.000000    ...     0.096220  0.000000       0.0  0.000000
# 2  0.000000  0.012282    ...     0.159710  0.619182       0.0  0.000000
# 3  0.000000  0.000000    ...     0.000000  0.144147       0.0  0.000000
# 4  0.000000  0.000000    ...     0.000000  0.096138       0.0  0.049107
#
#    topic_16  topic_17  topic_18  topic_19  topic_20  topic_21
# 0  0.022498  0.000000  0.017039  0.000000  0.026408  0.009009
# 1  0.000000  0.000000  0.000000  0.000000  0.169497  0.000000
# 2  0.000000  0.000000  0.000000  0.098381  0.000000  0.110445
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.059107  0.005616  0.000000  0.008203  0.147644  0.000000
#
# [5 rows x 25 columns]

# %%
joined['date'] = ['{}-{:02d}-01'.format(a, b) for a, b in joined[['year', 'month']].values]
cols = [c for c in joined.columns if c.startswith('topic')]

joined.head()
# Out:
#    docID  year  month   topic_0   topic_1  topic_2  topic_3   topic_4  \
# 0      0  2008      2  0.433729  0.000000      0.0      0.0  0.021411
# 1      1  2008      2  0.595476  0.000000      0.0      0.0  0.000000
# 2      2  2008      2  0.000000  0.000000      0.0      0.0  0.000000
# 3      3  2008      2  0.000000  0.184165      0.0      0.0  0.000000
# 4      4  2008      2  0.000000  0.000000      0.0      0.0  0.000000
#
#     topic_5   topic_6     ...      topic_13  topic_14  topic_15  topic_16  \
# 0  0.002973  0.047639     ...      0.193255       0.0  0.000000  0.022498
# 1  0.000000  0.000000     ...      0.000000       0.0  0.000000  0.000000
# 2  0.000000  0.012282     ...      0.619182       0.0  0.000000  0.000000
# 3  0.000000  0.000000     ...      0.144147       0.0  0.000000  0.000000
# 4  0.000000  0.000000     ...      0.096138       0.0  0.049107  0.059107
#
#    topic_17  topic_18  topic_19  topic_20  topic_21        date
# 0  0.000000  0.017039  0.000000  0.026408  0.009009  2008-02-01
# 1  0.000000  0.000000  0.000000  0.169497  0.000000  2008-02-01
# 2  0.000000  0.000000  0.098381  0.000000  0.110445  2008-02-01
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  2008-02-01
# 4  0.005616  0.000000  0.008203  0.147644  0.000000  2008-02-01
#
# [5 rows x 26 columns]

# %%
dd = joined[cols + ['date']].melt('date', var_name='topic', value_name='mentions')
dd = dd[dd['mentions'] > 0]

dd2 = dd.groupby(['date','topic']).sum()

dd2=dd2.reset_index()

dd.head()
# Out:
#          date    topic  mentions
# 0  2008-02-01  topic_0  0.433729
# 1  2008-02-01  topic_0  0.595476
# 7  2008-02-01  topic_0  0.672846
# 8  2008-02-01  topic_0  0.002393
# 9  2008-02-01  topic_0  0.043576

# %%
labels = sorted(joined['date'].unique())
fig, axes = joypy.joyplot(dd2, by='topic', column='mentions', figsize=(20, 20),
                          xlabelsize=20,ylabelsize=20,
                          overlap=0.4, fill=True,
                          linecolor="k",linewidth=3,
                          kind='values', fade=True, xrot=90,
                          x_range=[i for i in range(len(labels))],
                          background='white');

ticks_labels = {i:t for i, t in enumerate(labels)}
axes[-1].set_xticks([k for k, v in ticks_labels.items() if k % 6 == 0])
ticks = axes[-1].get_xticks()
axes[-1].set_xticklabels([ticks_labels.get(i, 'stop') for i in ticks]);

# %%
fig.savefig(f"data/visualization/{'-'.join(name_dataset.split('.'))}_joypy")
