# %%
import pyLDAvis.gensim
from pipeline import TopicModeller
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
df = pd.read_csv('data/novayagazeta.ru.txt', encoding='utf-8', sep='\t', header=None)
df.columns = ['id', 'url', 'title', 'text']

# %%
#tm = TopicModeller('data/news_lenta.csv')
tm = TopicModeller(df=df)

# %%
new_data = tm.data[2000:2100]

# %%
tm.data = tm.data[:1000]

# %%
tm.process()
# Out:
# ............Start process.
# Starting processing
# Cleaning
# Normalizing
# ............End process. Time: 2.14 sec.

# %%
tm.prepare_data_gensim(dict_path='dict.dictionary')
# Out:
# ............Start prepare_data_gensim.
# ............End prepare_data_gensim. Time: 0.50 sec.

# %%
params = {'num_topics':3,
          'passes':1,
          'alpha':'auto',
          'eta':None,
          'random_state':42}
tm.build_model_gensim(params);
# Out:
# ............Start build_model_gensim.
# Perplexity: -10.33610654820514
# Coherence Score: 0.3124475241238393
# ............End build_model_gensim. Time: 12.20 sec.

# %%
panel = tm.visualize()
# Out:
# ....Start visualize.
# ....End visualize. Time: 3.03 sec.

# %%
t = tm.extract_topics_gensim(texts=list(new_data['text'].values))
t[:2]
# Out:
# ............Start extract_topics_gensim.
# ................100
# ................Start process.
# Starting processing
# Cleaning
# Normalizing
# ................End process. Time: 0.17 sec.
# ................[['сбу', 'плену', 'сепаратистов', 'остаются', 'украинских', 'силовиков', 'плену', 'сепаратистов', 'народных', 'республик', 'прежнему', 'находятся', 'украинских', 'силовиков', 'заявил', 'эфире', 'телеканала', 'украина', 'советник', 'главы', 'сбу', 'маркиян', 'лубкивский', 'человек', 'остаются', 'плену', 'определенное', 'число', 'пропало', 'вести', 'ищем', 'цитирует', 'лубкивского', 'риа', 'новости', 'момента', 'подписания', 'соглашения', 'временном', 'прекращении', 'огня', 'сентября', 'минске', 'сепаратисты', 'освободили', 'тысячи', 'человек', 'последние', 'несколько', 'недель', 'отметил', 'советник', 'главы', 'службы', 'безопасности', 'украины', 'будут', 'освобождены', 'оставшиеся', 'пленные', 'лубкиевский', 'уточнил', 'мнению', 'процесс', 'займет', 'несколько', 'месяцев'], ['американец', 'заразившийся', 'вирусом', 'эбола', 'контактировал', 'детьми', 'житель', 'техасского', 'города', 'даллас', 'которого', 'диагностирована', 'лихорадка', 'эбола', 'контактировал', 'детьми', 'школьного', 'возраста', 'сообщает', 'reuters', 'пятеро', 'детей', 'пошли', 'школу', 'начале', 'недели', 'находятся', 'наблюдением', 'губернатор', 'штата', 'рик', 'перри', 'заверил', 'власти', 'штата', 'способны', 'предотвратить', 'распространение', 'вируса', 'риск', 'вспышки', 'эпидемии', 'техасе', 'оценил', 'минимальный', 'напомним', 'первом', 'американце', 'заразившемся', 'вирусом', 'эбола', 'стало', 'известно', 'вчера', 'пациент', 'чье', 'имя', 'сообщалось', 'госпитализирован', 'инфекционный', 'изолятор', 'далласа', 'американец', 'вернулся', 'техас', 'либерии', 'транзитом', 'брюссель', 'пресвитерианской', 'больнице', 'находится', 'мужчина', 'сообщили', 'состояние', 'тяжелое', 'данным', 'американского', 'агентства', 'джи', 'мелиш', 'который', 'назвал', 'другом', 'семьи', 'заразившегося', 'мужчины', 'рассказал', 'имя', 'пострадавшего', 'томас', 'эрик', 'дункан', 'августе', 'либерии', 'сша', 'доставлены', 'несколько', 'американских', 'медработников', 'которых', 'диагностировали', 'лихорадку', 'эбола', 'трое', 'экспериментального', 'лечения', 'выписаны', 'больницы'], ['жителя', 'амурской', 'области', 'изъято', 'кг', 'высушенной', 'марихуаны', 'наркополиция', 'изъяла', 'жителя', 'амурской', 'области', 'килограммов', 'высушенной', 'марихуаны', 'сообщает', 'сайт', 'фскн', 'амурской', 'области', 'рекордная', 'партия', 'наркотиков', 'начала', 'нынешнего', 'года', 'сотрудниками', 'фскн', 'получено', 'анонимное', 'сообщение', 'котором', 'сказано', 'крупная', 'партия', 'наркотиков', 'находится', 'окрестностях', 'села', 'ленино', 'проверке', 'обнаружены', 'пологов', 'мешков', 'высушенной', 'марихуаной', 'общим', 'весом', 'килограмма', 'месте', 'обнаружения', 'марихуаны', 'наркополицейские', 'задержали', 'мужчину', 'который', 'упаковывал', 'наркотик', 'мешки', 'задержанный', 'рассказал', 'собирал', 'дикорастущую', 'коноплю', 'бурейском', 'районе', 'перевозил', 'мотоцикле', 'оставлял', 'лесу', 'словам', 'мужчины', 'заготовил', 'наркотик', 'собственного', 'потребления', 'марихуаны', 'хватило', 'лет', 'житель', 'амурской', 'области', 'признался', 'планировал', 'искать', 'покупателей', 'отношении', 'мужчины', 'возбуждено', 'уголовное', 'дело', 'статье', 'ук', 'рф', 'приготовление', 'сбыту', 'веществ', 'грозит', 'лет', 'лишения', 'свободы'], ['астахов', 'российских', 'детей', 'уехавших', 'сша', 'обмену', 'вернулись', 'домой', 'детей', 'приехавших', 'сша', 'различным', 'программам', 'обмена', 'вернулись', 'домой', 'интервью', 'российской', 'газете', 'рассказал', 'уполномоченный', 'правам', 'ребенка', 'павел', 'астахов', 'словам', 'астахова', 'такая', 'практика', 'новость', 'первый', 'год', 'российские', 'дети', 'выезжают', 'сша', 'культурным', 'реабилитационным', 'туристическим', 'программам', 'остаются', 'сегодня', 'минимум', 'полтора', 'десятка', 'таких', 'ребят', 'такими', 'случаями', 'занимаемся', 'говорит', 'уполномоченный', 'правам', 'ребенка', 'американский', 'посол', 'москве', 'джон', 'теффт', 'ранее', 'говорил', 'российские', 'власти', 'приняли', 'ре ...
# ............End extract_topics_gensim. Time: 0.17 sec.
# [['сбу',
#   'плену',
#   'сепаратистов',
#   'остаются',
#   'украинских',
#   'силовиков',
#   'плену',
#   'сепаратистов',
#   'народных',
#   'республик',
#   'прежнему',
#   'находятся',
#   'украинских',
#   'силовиков',
#   'заявил',
#   'эфире',
#   'телеканала',
#   'украина',
#   'советник',
#   'главы',
#   'сбу',
#   'маркиян',
#   'лубкивский',
#   'человек',
#   'остаются',
#   'плену',
#   'определенное',
#   'число',
#   'пропало',
#   'вести',
#   'ищем',
#   'цитирует',
#   'лубкивского',
#   'риа',
#   'новости',
#   'момента',
#   'подписания',
#   'соглашения',
#   'временном',
#   'прекращении',
#   'огня',
#   'сентября',
#   'минске',
#   'сепаратисты',
#   'освободили',
#   'тысячи',
#   'человек',
#   'последние',
#   'несколько',
#   'недель',
#   'отметил',
#   'советник',
#   'главы',
#   'службы',
#   'безопасности',
#   'украины',
#   'будут',
#   'освобождены',
#   'оставшиеся',
#   'пленные',
#   'лубкиевский',
#   'уточнил',
#   'мнению',
#   'процесс',
#   'займет',
#   'несколько',
#   'месяцев'],
#  ['американец',
#   'заразившийся',
#   'вирусом',
#   'эбола',
#   'контактировал',
#   'детьми',
#   'житель',
#   'техасского',
#   'города',
#   'даллас',
#   'которого',
#   'диагностирована',
#   'лихорадка',
#   'эбола',
#   'контактировал',
#   'детьми',
#   'школьного',
#   'возраста',
#   'сообщает',
#   'reuters',
#   'пятеро',
#   'детей',
#   'пошли',
#   'школу',
#   'начале',
#   'недели',
#   'находятся',
#   'наблюдением',
#   'губернатор',
#   'штата',
#   'рик',
#   'перри',
#   'заверил',
#   'власти',
#   'штата',
#   'способны',
#   'предотвратить',
#   'распространение',
#   'вируса',
#   'риск',
#   'вспышки',
#   'эпидемии',
#   'техасе',
#   'оценил',
#   'минимальный',
#   'напомним',
#   'первом',
#   'американце',
#   'заразившемся',
#   'вирусом',
#   'эбола',
#   'стало',
#   'известно',
#   'вчера',
#   'пациент',
#   'чье',
#   'имя',
#   'сообщалось',
#   'госпитализирован',
#   'инфекционный',
#   'изолятор',
#   'далласа',
#   'американец',
#   'вернулся',
#   'техас',
#   'либерии',
#   'транзитом',
#   'брюссель',
#   'пресвитерианской',
#   'больнице',
#   'находится',
#   'мужчина',
#   'сообщили',
#   'состояние',
#   'тяжелое',
#   'данным',
#   'американского',
#   'агентства',
#   'джи',
#   'мелиш',
#   'который',
#   'назвал',
#   'другом',
#   'семьи',
#   'заразившегося',
#   'мужчины',
#   'рассказал',
#   'имя',
#   'пострадавшего',
#   'томас',
#   'эрик',
#   'дункан',
#   'августе',
#   'либерии',
#   'сша',
#   'доставлены',
#   'несколько',
#   'американских',
#   'медработников',
#   'которых',
#   'диагностировали',
#   'лихорадку',
#   'эбола',
#   'трое',
#   'экспериментального',
#   'лечения',
#   'выписаны',
#   'больницы'],
#  ['жителя',
#   'амурской',
#   'области',
#   'изъято',
#   'кг',
#   'высушенной',
#   'марихуаны',
#   'наркополиция',
#   'изъяла',
#   'жителя',
#   'амурской',
#   'области',
#   'килограммов',
#   'высушенной',
#   'марихуаны',
#   'сообщает',
#   'сайт',
#   'фскн',
#   'амурской',
#   'области',
#   'рекордная',
#   'партия',
#   'наркотиков',
#   'начала',
#   'нынешнего',
#   'года',
#   'сотрудниками',
#   'фскн',
#   'получено',
#   'анонимное',
#   'сообщение',
#   'котором',
#   'сказано',
#   'крупная',
#   'партия',
#   'наркотиков',
#   'находится',
#   'окрестностях',
#   'села',
#   'ленино',
#   'проверке',
#   'обнаружены',
#   'пологов',
#   'мешков',
#   'высушенной',
#   'марихуаной',
#   'общим',
#   'весом',
#   'килограмма',
#   'месте',
#   'обнаружения',
#   'марихуаны',
#   'наркополицейские',
#   'задержали',
#   'мужчину',
#   'который',
#   'упаковывал',
#   'наркотик',
#   'мешки',
#   'задержанный',
#   'рассказал',
#   'собирал',
#   'дикорастущую',
#   'коноплю',
#   'бурейском',
#   'районе',
#   'перевозил',
#   'мотоцикле',
#   'оставлял',
#   'лесу',
#   'словам',
#   'мужчины',
#   'заготовил',
#   'наркотик',
#   'собственного',
#   'потребления',
#   'марихуаны',
#   'хватило',
#   'лет',
#   'житель',
#   'амурской',
#   'области',
#   'признался',
#   'планировал',
#   'искать',
#   'покупателей',
#   'отношении',
#   'мужчины',
#   'возбуждено',
#   'уголовное',
#   'дело',
#   'статье',
#   'ук',
#   'рф',
#   'приготовление',
#   'сбыту',
#   'веществ',
#   'грозит',
#   'лет',
#   'лишения',
#   'свободы'],
#  ['астахов',
#   'российских',
#   'детей',
#   'уехавших',
#   'сша',
#   'обмену',
#   'вернулись',
#   'домой',
#   'детей',
#   'приехавших',
#   'сша',
#   'различным',
#   'программам',
#   'обмена',
#   'вернулись',
#   'домой',
#   'интервью',
#   'российской',
#   'газете',
#   'рассказал',
#   'уполномоченный',
#   'правам',
#   'ребенка',
#   'павел',
#   'астахов',
#   'словам',
#   'астахова',
#   'такая',
#   'практика',
#   'новость',
#   'первый',
#   'год',
#   'российские',
#   'дети',
#   'выезжают',
#   'сша',
#   'культурным',
#   'реабилитационным',
#   'туристическим',
#   'программам',
#   'остаются',
#   'сегодня',
#   'минимум',
#   'полтора',
#   'десятка',
#   'таких',
#   'ребят',
#   'такими',
#   'случаями',
#   'занимаемся',
#   'говорит',
#   'уполномоченный',
#   'правам',
#   'ребенка',
#   'американский',
#   'посол',
#   'москве',
#   'джон',
#   'теффт',
#   'ранее',
#   'говорил',
#   'российские',
#   'власти',
#   'приняли',
#   'решение',
#   'приостановке',
#   'участия',
#   'программе',
#   'flex',
#   'российских',
#   'школьников',
#   'согласно',
#   'условиям',
#   'программы',
#   'российские',
#   'дети',
#   'могут',
#   'бесплатно',
#   'учиться',
#   'живя',
#   'американской',
#   'семье'],
#  ['таиланде',
#   'катаясь',
#   'мотоцикле',
#   'погиб',
#   'россиянин',
#   'летний',
#   'гражданин',
#   'россии',
#   'погиб',
#   'катаясь',
#   'мотоцикле',
#   'таиландском',
#   'острове',
#   'пхукет',
#   'сообщает',
#   'местное',
#   'издание',
#   'phuket',
#   'wan',
#   'медработники',
#   'нашли',
#   'тело',
#   'мужчины',
#   'лежавшее',
#   'тротуаре',
#   'лагуне',
#   'около',
#   'пляжа',
#   'най',
#   'харн',
#   'согласно',
#   'предварительной',
#   'версии',
#   'мужчина',
#   'справился',
#   'управлением',
#   'врезался',
#   'бордюр',
#   'результате',
#   'падения',
#   'сломал',
#   'шею',
#   'данным',
#   'полиции',
#   'защитного',
#   'шлема',
#   'погибшем',
#   'подобные',
#   'смерти',
#   'редкость',
#   'пхукета',
#   'имя',
#   'погибшего',
#   'пока',
#   'афишируется',
#   'поскольку',
#   'родственники',
#   'возможно',
#   'пока',
#   'знают',
#   'случившемся']]

# %%
tm.update_gensim_model(texts=list(new_data['text'].values))
# Out:
# ............Start update_gensim_model.
# ................Start process.
# Starting processing
# Cleaning
# Normalizing
# ................End process. Time: 0.17 sec.
# ............End update_gensim_model. Time: 0.39 sec.
