# %% [markdown]
# # Dynamic topic modelling via Non-negative Matrix Factorization (NMF)

# %% [markdown]
# Warning: running the whole notebook requires more than 16Gb RAM.
# However you can run steps 1 and 2 separately

# %%
! pip3 install gensim
! pip3 install razdel
! pip3 install pymorphy2

# %% [markdown]
# Import some preprocessing tools

# %%
import sys
sys.path.insert(0, '../../../preprocessing')
import preprocessing_tools_updt as preprocessing_tools

# %%
import pandas as pd;
import numpy as np;
import scipy as sp;
import sklearn;
import sys;
from nltk.corpus import stopwords;
import nltk;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
import re;
from io import StringIO;
from nltk.corpus import stopwords
import gc

# %% [markdown]
# # Step 1: Preprocessing

# %% [markdown]
# Here we will process input .csv line by line as far as the separator "|" happens to be a part of the message body for some entries

# %%
date  = []
url   = []
host  = []
topic = []
title = []
body  = []
with open('../../../../../../project_news/interfax_sorted_2008-02-11_2019-01-19.csv') as news_file:
    for line in news_file:
        fields = line.split("|")
        date.append(fields[0])
        url.append(fields[1])
        host.append(fields[2])
        topic.append(fields[3])
        title.append(fields[4])
        body.append(" ".join(fields[5:]))
    news_file.close()
data_prep = pd.DataFrame({'date' : date,
                          'url'  : url,
                          'host' : host,
                          'topic': topic,
                          'title': title,
                          'body' : body},
                         columns={'date', 'url', 'host', 'topic', 'title', 'body'})
data_prep.info()

# %%
data = pd.read_csv('../../../../../../project_news/interfax_sorted_2008-02-11_2019-01-19.csv',
                   sep='|',
                   encoding='utf-8',
                   error_bad_lines=False);
data.columns = ["date", "url", "host", "topic", "title", "body"]
data.info()
# Out:
# b'Skipping line 100300: expected 6 fields, saw 14\n'
# b'Skipping line 138281: expected 6 fields, saw 7\nSkipping line 139718: expected 6 fields, saw 7\nSkipping line 184612: expected 6 fields, saw 7\nSkipping line 184720: expected 6 fields, saw 7\nSkipping line 188784: expected 6 fields, saw 8\nSkipping line 197770: expected 6 fields, saw 12\nSkipping line 201959: expected 6 fields, saw 7\nSkipping line 226778: expected 6 fields, saw 7\n'
# b'Skipping line 332321: expected 6 fields, saw 8\nSkipping line 388909: expected 6 fields, saw 7\n'
# b'Skipping line 393299: expected 6 fields, saw 7\nSkipping line 394088: expected 6 fields, saw 7\nSkipping line 396155: expected 6 fields, saw 7\nSkipping line 397254: expected 6 fields, saw 7\nSkipping line 397433: expected 6 fields, saw 10\nSkipping line 397542: expected 6 fields, saw 12\nSkipping line 398285: expected 6 fields, saw 14\nSkipping line 398351: expected 6 fields, saw 7\nSkipping line 401967: expected 6 fields, saw 9\nSkipping line 403339: expected 6 fields, saw 7\nSkipping line 404888: expected 6 fields, saw 7\nSkipping line 407453: expected 6 fields, saw 7\nSkipping line 409289: expected 6 fields, saw 7\nSkipping line 411112: expected 6 fields, saw 7\nSkipping line 412728: expected 6 fields, saw 8\nSkipping line 415209: expected 6 fields, saw 7\nSkipping line 422773: expected 6 fields, saw 10\nSkipping line 422969: expected 6 fields, saw 7\nSkipping line 426090: expected 6 fields, saw 7\nSkipping line 427211: expected 6 fields, saw 7\nSkipping line 428914: expected 6 fields, saw 7\nSkipping line 441468: expected 6 fields, saw 7\nSkipping line 441590: expected 6 fields, saw 8\nSkipping line 441596: expected 6 fields, saw 8\nSkipping line 445039: expected 6 fields, saw 7\nSkipping line 445125: expected 6 fields, saw 8\nSkipping line 445800: expected 6 fields, saw 7\nSkipping line 445806: expected 6 fields, saw 7\nSkipping line 448528: expected 6 fields, saw 7\nSkipping line 448660: expected 6 fields, saw 7\nSkipping line 449543: expected 6 fields, saw 7\nSkipping line 449983: expected 6 fields, saw 7\nSkipping line 450502: expected 6 fields, saw 7\nSkipping line 451742: expected 6 fields, saw 7\nSkipping line 455128: expected 6 fields, saw 7\nSkipping line 455696: expected 6 fields, saw 7\nSkipping line 456242: expected 6 fields, saw 7\nSkipping line 457404: expected 6 fields, saw 12\nSkipping line 461257: expected 6 fields, saw 12\nSkipping line 461512: expected 6 fields, saw 7\nSkipping line 461831: expected 6 fields, saw 7\nSkipping line 462065: expected 6 fields, saw 7\nSkipping line 462656: expected 6 fields, saw 7\nSkipping line 462659: expected 6 fields, saw 7\nSkipping line 462661: expected 6 fields, saw 7\nSkipping line 462670: expected 6 fields, saw 7\nSkipping line 463723: expected 6 fields, saw 8\nSkipping line 464834: expected 6 fields, saw 12\nSkipping line 465105: expected 6 fields, saw 7\nSkipping line 465976: expected 6 fields, saw 8\nSkipping line 468024: expected 6 fields, saw 7\nSkipping line 470455: expected 6 fields, saw 7\nSkipping line 475545: expected 6 fields, saw 7\nSkipping line 476165: expected 6 fields, saw 9\nSkipping line 476591: expected 6 fields, saw 7\nSkipping line 480271: expected 6 fields, saw 7\nSkipping line 481930: expected 6 fields, saw 7\nSkipping line 482694: expected 6 fields, saw 8\nSkipping line 483550: expected 6 fields, saw 7\nSkipping line 488160: expected 6 fields, saw 9\nSkipping line 488617: expected 6 fields, saw 7\nSkipping line 488866: expected 6 fields, saw 7\nSkipping line 489459: expected 6 fields, saw 7\nSkipping line 491636: expected 6 fields, saw 7\nSkipping line 497509: expected 6 fields, saw 10\nSkipping line 497865: expected 6 fields, saw 8\nSkipping line 498067: expected 6 fields, saw 7\nSkipping line 498979: expected 6 fields, saw 8\nSkipping line 499239: expected 6 fields, saw 7\nSkipping line 502766: expected 6 fields, saw 7\nSkipping line 502844: expected 6 fields, saw 7\nSkipping line 504289: expected 6 fields, saw 7\nSkipping line 505084: expected 6 fields, saw 12\nSkipping line 506069: expected 6 fields, saw 7\nSkipping line 508137: expected 6 fields, saw 7\nSkipping line 509285: expected 6 fields, saw 7\nSkipping line 509761: expected 6 fields, saw 7\nSkipping line 511419: expected 6 fields, saw 8\nSkipping line 512494: expected 6 fields, saw 8\nSkipping line 512516: expected 6 fields, saw 8\nSkipping line 512837: expected 6 fields, saw 8\nSkipping line 512984: expected 6 fields, saw 8\nSkipping line 514403: expected 6 fields, saw 7\nSkipp ...
# b'Skipping line 524529: expected 6 fields, saw 7\nSkipping line 524990: expected 6 fields, saw 7\n'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529025 entries, 0 to 529024
# Data columns (total 6 columns):
# date     529025 non-null object
# url      529025 non-null object
# host     529025 non-null object
# topic    529025 non-null object
# title    529025 non-null object
# body     529025 non-null object
# dtypes: object(6)
# memory usage: 24.2+ MB

# %% [markdown]
# As we can see, 106 entries are lost due to extra separators. However, I assume, it is not critical.

# %%
del data_prep
del date
del url
del host
del topic
del title
del body
gc.collect()

# %%
data["cleaned_text"] = data["body"].apply(preprocessing_tools.clean_text)
data[["cleaned_text"]].head()
# Out:
#                                         cleaned_text
# 0  барнаул  февраля interfaxru  первый городской ...
# 1  чита  февраля interfaxru  эксглава нк юкос мих...
# 2  москва  февраля interfaxru  в результате пожар...
# 3  токио  февраля interfaxru  рост ввп россии в  ...
# 4  москва  февраля interfaxru  цены на нефть выро...

# %%
stopword_ru = stopwords.words('russian')
data["tokenized_text"] = data["cleaned_text"].apply(preprocessing_tools.lemmatization, stopword=stopword_ru)
data[["tokenized_text"]].head()
# Out:
#                                       tokenized_text
# 0  [барнаул, февраль, interfaxru, городской, чемп...
# 1  [чита, февраль, interfaxru, эксглава, нк, юкос...
# 2  [москва, февраль, interfaxru, результат, пожар...
# 3  [токио, февраль, interfaxru, рост, ввп, россия...
# 4  [москва, февраль, interfaxru, цена, нефть, выр...

# %% [markdown]
# NMF expects input texts as strings

# %%
tockens_clean = data["tokenized_text"].tolist()
texts_clean = [" ".join(x) for x in tockens_clean]

# %%
del data
gc.collect()
# Out:
# 70

# %% [markdown]
# Save preprocessed texts into a file

# %%
with open('./clean.texts.txt', 'wt') as out_file:
    for doc in texts_clean:
        out_file.write(doc + '\n')
    out_file.close()

# %% [markdown]
# # Step 2: Topic modelling

# %% [markdown]
# Now we will read the preprocessed data

# %%
documents = []
with open('clean.texts.txt', 'rt') as in_file:
    for line in in_file:
        documents.append(line.rstrip())
    in_file.close()

# %%
documents[0]
# Out:
# 'барнаул февраль interfaxru городской чемпионат ледолазание проходить воскресение барнаул надеяться проведение подобный чемпионат стать барнаул традиция сказать выступать церемония открытие чемпионат представитель федерация ледоскалолазание алтайский край выступить организатор соревнование сообщить корреспондент агентство интерфакссибирь соревнование проводиться среди мужчина женщина также вид парный гонка участник использование специальный снаряжение необходимый время забраться специально изготовить сосулька высота трехэтажный дом слово представитель организатор чемпионат олег язовский основной контингент участник любитель спортсмен иметь спортивный разряд'

# %%
max_features = 3000
vectorizer = CountVectorizer(analyzer='word', max_features=max_features);
x_counts = vectorizer.fit_transform(documents);
print(x_counts.shape)
# Out:
# (529025, 3000)

# %%
transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %% [markdown]
# Let us decompose the document-term matrix and experiment with the number of topics

# %% [markdown]
# 200 topics

# %%
num_topics = 200
model = NMF(n_components=num_topics, init='nndsvd');
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=200, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
# https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
topics = get_nmf_topics(model, 20)
topics
# Out:
#           Topic # 01       Topic # 02   Topic # 03   Topic # 04  \
# 0          интерфакс        произойти        рубль         матч
# 1           сообщить         инцидент    составить      стадион
# 2             москва          причина       размер         игра
# 3            сказать       возгорание     триллион    болельщик
# 4              среда           авария        сумма          тур
# 5      корреспондент  предварительный    стоимость       против
# 6           источник       пострадать        штраф       футбол
# 7          столичный     происшествие        доход   футбольный
# 8         interfaxru   обстоятельство     денежный      сыграть
# 9         московский           данные     средство           го
# 10             слово        обрушение        ущерб       минута
# 11          отметить            шахта     похитить          гол
# 12  пресссекретарить            драка      выплата          пол
# 13        собеседник            около   московский       первое
# 14        передавать            никто  минимальный       пройти
# 15          добавить  устанавливаться       доллар       забить
# 16      подмосковный              изз          ооо  премьерлига
# 17              пока        результат     квартира    групповой
# 18       подмосковье            утром        билет    чемпионат
# 19          уточнить         трагедия       расчёт   состояться
#
#         Topic # 05     Topic # 06    Topic # 07   Topic # 08     Topic # 09  \
# 0             дело          пожар       самолёт       индекс          город
# 1        уголовный     возгорание          борт         ммвб         житель
# 2        возбудить       пожарный       посадка        пункт        местный
# 3               ук  ликвидировать      крушение          ртс      городской
# 4               ст        тушение         пилот     фондовый         власть
# 5        отношение          огонь            ан         торг  администрация
# 6           статья         лесной     разбиться        биржа          часть
# 7             факт         гореть      вылететь      вырасти       памятник
# 8    расследование             кв    катастрофа        рынок           штат
# 9      возбуждение     возникнуть     совершить          фон    расположить
# 10            лицо           метр        лайнер  большинство          север
# 11      незаконный          склад      пассажир       упасть    центральный
# 12             скр             га  пассажирский     рублёвый      население
# 13       следствие     квадратный  авиакомпания        акция           вода
# 14    преступление           этаж     двигатель     площадка             юг
# 15        материал      сложность      аэродром    составить         алеппо
# 16      причинение        причина    находиться       предел    севастополь
# 17  неосторожность        единица   авиационный       бумага      сирийский
# 18        фигурант        техника     воздушный    открыться        крупный
# 19     должностной             гу           ввс         итог           весь
#
#         Topic # 10       ...         Topic # 90      Topic # 91  \
# 0        сообщение       ...           вертолёт     космический
# 1       говориться       ...                 ми         аппарат
# 2       отмечаться       ...           крушение         спутник
# 3        поступить       ...            посадка          орбита
# 4        заявление       ...               борт       космодром
# 5   распространить       ...              пилот          запуск
# 6       прессрелиз       ...              поиск       роскосмос
# 7        ведомство       ...          спасатель        байконур
# 8       разместить       ...          разбиться            блок
# 9            немой       ...         катастрофа             мкс
# 10           связь       ...             упасть            союз
# 11    опубликовать       ...            жёсткий         вывести
# 12  подчёркиваться       ...             экипаж           земля
# 13      уточняться       ...            падение  интерфаксуавна
# 14            весь       ...           пропасть          космос
# 15    министерство       ...         находиться         система
# 16     приводиться       ...          совершить       запустить
# 17        согласно       ...        авиационный           старт
# 18        лицензия       ...          воздушный       космонавт
# 19             это       ...           километр      стартовать
#
#        Topic # 92     Topic # 93  Topic # 94    Topic # 95       Topic # 96  \
# 0          осетия         ноябрь      январь       полиция          решение
# 1           южный         москва      москва   полицейский          принять
# 2         абхазия     interfaxru  interfaxru     сотрудник          участие
# 3      грузинский             мх  новогодний         отдел        принимать
# 4        северный          месяц   австралия       местный    окончательный
# 5   независимость          конец          ск     столичный         принятие
# 6          эдуард           марш        снег      стрельба             мера
# 7         граница     состояться  домодедово        главка            связь
# 8       признание           дата       минус          умвд         комиссия
# 9        конфликт       итоговый    открытый     доставить   процессуальный
# 10             лр         саммит        ночь       порядок      руководство
# 11          поток       середина     транзит    арестовать  соответствующий
# 12        сторона          париж       месяц      инцидент         отменить
# 13          корея         казань        сбор     несколько           решить
# 14       закрытый       послание    праздник            гу        заседание
# 15    наблюдатель      перенести   казахстан   подозревать       обжаловать
# 16    интерфаксюг             го  сообщаться       прибыть            отказ
# 17           село  информировать   перенести       армения      приниматься
# 18             вб        аукцион       новое  протестовать    приостановить
# 19             мх       наметить        дата    задержание         проблема
#
#     Topic # 97        Topic # 98      Topic # 99
# 0    чемпионат           декабрь   правительство
# 1          мир            москва  премьерминистр
# 2       футбол        interfaxru     вицепремьер
# 3      сборная        новогодний       заседание
# 4       европа             пермь        киргизия
# 5    проходить                ск    распоряжение
# 6         фифа          пермский         кабинет
# 7     бразилия  прессконференция         премьер
# 8       хоккей        состояться   постановление
# 9     открытый             конец       временной
# 10       спорт                мх    председатель
# 11      лёгкий                ii        отставка
# 12    выиграть              дата           новое
# 13   австралия              снег        поручить
# 14    германия         перенести     предложение
# 15      канада          праздник        премьера
# 16   федерация          послание    сформировать
# 17  проведение            вокзал       парламент
# 18      москва          массовый       утвердить
# 19     мировой          середина       совещание
#
# [20 rows x 200 columns]

# %% [markdown]
# While some topics are pretty clear:
# Topic #1 - что-то связанное с передачей информации
# Topic #2 - происшествия, несчастные случаи
# Topic #3 - финансы, валюта
# Topic #4 - футбол
# Topic #5 - судебные дела
# Topic #6 - пожары
# Topic #7 - инциденты с авиационной техникой
# ...
#
# Nevertheless, some topics overlap (like 7 and 90)

# %%
topics.to_csv('../nmf.topics.%d.csv' % num_topics, )

# %% [markdown]
# 400 topics

# %%
num_topics = 400
model = NMF(n_components=num_topics, init='nndsvd');
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=400, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
topics400 = get_nmf_topics(model, 20)
topics400
# Out:
#           Topic # 01       Topic # 02     Topic # 03  Topic # 04  \
# 0          интерфакс        произойти       миллиард     сборная
# 1           сообщить         инцидент      составить      хоккей
# 2             москва   обстоятельство        объесть      швеция
# 3           отметить     происшествие         чистый   финляндия
# 4         interfaxru        обрушение        прибыль      канада
# 5          столичный            драка         резерв     женский
# 6           уточнить          причина        выручка       чехия
# 7   пресссекретарить  устанавливаться    увеличиться   групповой
# 8          поступить         трагедия       триллион   швейцария
# 9              ранее          событие        внешний    норвегия
# 10             слово            утром            куб    обыграть
# 11        собеседник          вечером        вырасти      первое
# 12            главка         конфликт         убыток   проходить
# 13          добавить        случиться        капитал     сыграть
# 14      подмосковный             факт        квартал  молодёжный
# 15                мх       уточняться      снизиться    бразилия
# 16           евгений             ночь     показатель      третье
# 17              офис      подробность    сократиться        этап
# 18           наталья             утро     составлять        игра
# 19          владимир           упасть  капитализация   поражение
#
#        Topic # 05     Topic # 06    Topic # 07     Topic # 08      Topic # 09  \
# 0            дело          пожар       самолёт            мск           линия
# 1   расследование        тушение          борт          биржа    метрополитен
# 2      внутренний       пожарный       посадка    интерфаксюг           метро
# 3       уголовный  ликвидировать      крушение           торг       столичный
# 4        фигурант     возникнуть      вылететь         расчёт          прямая
# 5        материал         гореть            ан         завтра       увеличить
# 6        обвинять          склад     разбиться       начаться          упасть
# 7    рассмотрение        причина    катастрофа      составить    восстановить
# 8       следствие             кв        лайнер            час         телефон
# 9       свидетель      сложность  авиакомпания      состояние         падение
# 10          рамка     ликвидация     двигатель       вылететь     повреждение
# 11    прокуратура     пострадать  пассажирский         сессия          график
# 12       слушание     квадратный     совершить  приостановить     азербайджан
# 13         правый          номер      аэродром     стартовать          дерево
# 14    возбуждение        единица   авиационный         филиал           поезд
# 15     беспорядок         лесной         вылет    возобновить  осуществляться
# 16       судебный      полностью   вынужденный       торговый  электроэнергия
# 17  обвинительный        техника       причина  зафиксировать           утром
# 18         допрос          огонь     аварийный           ммвб            парк
# 19          судья        удаться   технический      краснодар        добавить
#
#        Topic # 10      ...         Topic # 90     Topic # 91  Topic # 92  \
# 0            июль      ...          спасатель         ноябрь      лондон
# 1          москва      ...              отряд         москва  британский
# 2      interfaxru      ...       спасательный     interfaxru      бибись
# 3              лр      ...       происшествие             мх         bbc
# 4           тариф      ...            прибыть       итоговый  корпорация
# 5      нидерланды      ...               гора          конец  передавать
# 6      официально      ...              берег           марш        news
# 7   краснодарский      ...              поиск       середина       ливия
# 8       полугодие      ...               река          месяц  лондонский
# 9         попытка      ...       эвакуировать     состояться  афганистан
# 10           лето      ...            удаться       послание      ссылка
# 11             де      ...              изпод           дата  арестовать
# 12         подъём      ...             спасти           олег      убитый
# 13          месяц      ...                лёд      революция     меньший
# 14       середина      ...          обрушение  информировать      тюрьма
# 15       крымский      ...          поступить          париж  основатель
# 16         лагерь      ...           спасение        таиланд        фунт
# 17        подпись      ...          оказаться         саммит    отмечать
# 18    подтвердить      ...         обрушиться       наметить       север
# 19       крушение      ...          поисковый          юрист      солдат
#
#         Topic # 93  Topic # 94      Topic # 95       Topic # 96    Topic # 97  \
# 0         средство      январь            крым          решение       команда
# 1         денежный      москва        крымский          принять         сезон
# 2     транспортный  interfaxru     севастополь    окончательный       формула
# 3           деньга  новогодний      полуостров         принятие     выступать
# 4          хищение   австралия  электроэнергия       обжаловать         игрок
# 5        кредитный  домодедово            порт   процессуальный          игра
# 6        бюджетный    праздник    черноморский  соответствующий  национальный
# 7             база     транзит      автономный         отменить        играть
# 8         выделить        сбор      республика      руководство    молодёжный
# 9    использование    открытый          кавказ           решить   руководство
# 10          размер       минус          житель         проблема      остаться
# 11           сумма       чехия            мост            отказ       партнёр
# 12  финансирование       собор         паспорт          вынести     следующий
# 13            цель    ресторан   краснодарский      приниматься       капитан
# 14        наркотик       новое         морской    приостановить     приводить
# 15         объесть    середина          статус        инстанция     последний
# 16     определение      зимний     вицепремьер           данный          очки
# 17    использовать       тариф      прекратить        основание         очень
# 18        вещество   екатерина         субъект           отмена      покинуть
# 19        привлечь    вступить       верховный    апелляционный       хороший
#
#           Topic # 98    Topic # 99
# 0          продукция  председатель
# 1   россельхознадзор   заместитель
# 2           поставка       комитет
# 3    роспотребнадзор     правление
# 4             запрет         съезд
# 5               ввоз     избранный
# 6           онищенко         борис
# 7               мясо     верховный
# 8        предприятие       госдума
# 9         санитарный           кнр
# 10       алкогольный           рад
# 11         запретить      владимир
# 12           продукт          союз
# 13             птица        палата
# 14       ограничение        андрей
# 15              вино        спикер
# 16     производитель     делегация
# 17          алкоголь       алексей
# 18        требование   кандидатура
# 19           выявить       избрать
#
# [20 rows x 400 columns]
