# %% [markdown]
# # Dynamic topic modelling via Non-negative Matrix Factorization (NMF)

# %%
! pip3 install gensim
! pip3 install razdel
! pip3 install pymorphy2
# Out:
# Requirement already satisfied: gensim in /home/anya/anaconda3/lib/python3.6/site-packages (3.7.1)
# Requirement already satisfied: six>=1.5.0 in /home/anya/anaconda3/lib/python3.6/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: smart-open>=1.7.0 in /home/anya/anaconda3/lib/python3.6/site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/anya/anaconda3/lib/python3.6/site-packages (from gensim) (1.13.3)
# Requirement already satisfied: scipy>=0.18.1 in /home/anya/anaconda3/lib/python3.6/site-packages (from gensim) (0.19.1)
# Requirement already satisfied: bz2file in /home/anya/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (0.98)
# Requirement already satisfied: boto>=2.32 in /home/anya/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (2.48.0)
# Requirement already satisfied: boto3 in /home/anya/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (1.9.106)
# Requirement already satisfied: requests in /home/anya/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (2.18.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/anya/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.7.0->gensim) (0.9.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.106 in /home/anya/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.7.0->gensim) (1.12.106)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /home/anya/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.7.0->gensim) (0.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/anya/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/anya/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/anya/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/anya/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (2017.7.27.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /home/anya/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.106->boto3->smart-open>=1.7.0->gensim) (2.6.1)
# Requirement already satisfied: docutils>=0.10 in /home/anya/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.106->boto3->smart-open>=1.7.0->gensim) (0.14)
# You are using pip version 18.0, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: razdel in /home/anya/anaconda3/lib/python3.6/site-packages (0.3.0)
# You are using pip version 18.0, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: pymorphy2 in /home/anya/anaconda3/lib/python3.6/site-packages (0.8)
# Requirement already satisfied: dawg-python>=0.7 in /home/anya/anaconda3/lib/python3.6/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in /home/anya/anaconda3/lib/python3.6/site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in /home/anya/anaconda3/lib/python3.6/site-packages (from pymorphy2) (2.4.393442.3710985)
# You are using pip version 18.0, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Import some preprocessing tools

# %%
import sys
sys.path.insert(0, '../../preprocessing') # /home/anya/project_news/proj_news_viz/nlp/preprocessing
import preprocessing_tools as preprocessing_tools

# %%
import pandas as pd;
import numpy as np;
import scipy as sp;
import sklearn;
import sys;
from nltk.corpus import stopwords;
import nltk;
from gensim.models import ldamodel
import gensim.corpora;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
import pickle;
import re;
from io import StringIO;
from nltk.corpus import stopwords

# %% [markdown]
# Here we will process input .csv line by line as far as the separator "|" happens to be a part of the message body

# %%
date  = []
url   = []
host  = []
topic = []
title = []
body  = []
with open('/home/anya/project_news/interfax_sorted_2008-02-11_2019-01-19.csv') as news_file:
    for line in news_file:
        fields = line.split("|")
        date.append(fields[0])
        url.append(fields[1])
        host.append(fields[2])
        topic.append(fields[3])
        title.append(fields[4])
        body.append(" ".join(fields[5:]))
data_prep = pd.DataFrame({'date' : date,
                          'url'  : url,
                         'host' : host,
                         'topic': topic,
                         'title': title,
                         'body' : body},
                         columns={'date', 'url', 'host', 'topic', 'title', 'body'})

# %%
data = pd.read_csv('/home/anya/project_news/interfax_sorted_2008-02-11_2019-01-19.csv',
                   sep='|',
                   encoding='utf-8',
                   error_bad_lines=False);
data.columns = ["date", "url", "host", "topic", "title", "body"]
data.info()
# Out:
# b'Skipping line 100300: expected 6 fields, saw 14\n'
# b'Skipping line 138281: expected 6 fields, saw 7\nSkipping line 139718: expected 6 fields, saw 7\nSkipping line 184612: expected 6 fields, saw 7\nSkipping line 184720: expected 6 fields, saw 7\nSkipping line 188784: expected 6 fields, saw 8\nSkipping line 197770: expected 6 fields, saw 12\nSkipping line 201959: expected 6 fields, saw 7\nSkipping line 226778: expected 6 fields, saw 7\n'
# b'Skipping line 332321: expected 6 fields, saw 8\nSkipping line 388909: expected 6 fields, saw 7\n'
# b'Skipping line 393299: expected 6 fields, saw 7\nSkipping line 394088: expected 6 fields, saw 7\nSkipping line 396155: expected 6 fields, saw 7\nSkipping line 397254: expected 6 fields, saw 7\nSkipping line 397433: expected 6 fields, saw 10\nSkipping line 397542: expected 6 fields, saw 12\nSkipping line 398285: expected 6 fields, saw 14\nSkipping line 398351: expected 6 fields, saw 7\nSkipping line 401967: expected 6 fields, saw 9\nSkipping line 403339: expected 6 fields, saw 7\nSkipping line 404888: expected 6 fields, saw 7\nSkipping line 407453: expected 6 fields, saw 7\nSkipping line 409289: expected 6 fields, saw 7\nSkipping line 411112: expected 6 fields, saw 7\nSkipping line 412728: expected 6 fields, saw 8\nSkipping line 415209: expected 6 fields, saw 7\nSkipping line 422773: expected 6 fields, saw 10\nSkipping line 422969: expected 6 fields, saw 7\nSkipping line 426090: expected 6 fields, saw 7\nSkipping line 427211: expected 6 fields, saw 7\nSkipping line 428914: expected 6 fields, saw 7\nSkipping line 441468: expected 6 fields, saw 7\nSkipping line 441590: expected 6 fields, saw 8\nSkipping line 441596: expected 6 fields, saw 8\nSkipping line 445039: expected 6 fields, saw 7\nSkipping line 445125: expected 6 fields, saw 8\nSkipping line 445800: expected 6 fields, saw 7\nSkipping line 445806: expected 6 fields, saw 7\nSkipping line 448528: expected 6 fields, saw 7\nSkipping line 448660: expected 6 fields, saw 7\nSkipping line 449543: expected 6 fields, saw 7\nSkipping line 449983: expected 6 fields, saw 7\nSkipping line 450502: expected 6 fields, saw 7\nSkipping line 451742: expected 6 fields, saw 7\nSkipping line 455128: expected 6 fields, saw 7\nSkipping line 455696: expected 6 fields, saw 7\nSkipping line 456242: expected 6 fields, saw 7\nSkipping line 457404: expected 6 fields, saw 12\nSkipping line 461257: expected 6 fields, saw 12\nSkipping line 461512: expected 6 fields, saw 7\nSkipping line 461831: expected 6 fields, saw 7\nSkipping line 462065: expected 6 fields, saw 7\nSkipping line 462656: expected 6 fields, saw 7\nSkipping line 462659: expected 6 fields, saw 7\nSkipping line 462661: expected 6 fields, saw 7\nSkipping line 462670: expected 6 fields, saw 7\nSkipping line 463723: expected 6 fields, saw 8\nSkipping line 464834: expected 6 fields, saw 12\nSkipping line 465105: expected 6 fields, saw 7\nSkipping line 465976: expected 6 fields, saw 8\nSkipping line 468024: expected 6 fields, saw 7\nSkipping line 470455: expected 6 fields, saw 7\nSkipping line 475545: expected 6 fields, saw 7\nSkipping line 476165: expected 6 fields, saw 9\nSkipping line 476591: expected 6 fields, saw 7\nSkipping line 480271: expected 6 fields, saw 7\nSkipping line 481930: expected 6 fields, saw 7\nSkipping line 482694: expected 6 fields, saw 8\nSkipping line 483550: expected 6 fields, saw 7\nSkipping line 488160: expected 6 fields, saw 9\nSkipping line 488617: expected 6 fields, saw 7\nSkipping line 488866: expected 6 fields, saw 7\nSkipping line 489459: expected 6 fields, saw 7\nSkipping line 491636: expected 6 fields, saw 7\nSkipping line 497509: expected 6 fields, saw 10\nSkipping line 497865: expected 6 fields, saw 8\nSkipping line 498067: expected 6 fields, saw 7\nSkipping line 498979: expected 6 fields, saw 8\nSkipping line 499239: expected 6 fields, saw 7\nSkipping line 502766: expected 6 fields, saw 7\nSkipping line 502844: expected 6 fields, saw 7\nSkipping line 504289: expected 6 fields, saw 7\nSkipping line 505084: expected 6 fields, saw 12\nSkipping line 506069: expected 6 fields, saw 7\nSkipping line 508137: expected 6 fields, saw 7\nSkipping line 509285: expected 6 fields, saw 7\nSkipping line 509761: expected 6 fields, saw 7\nSkipping line 511419: expected 6 fields, saw 8\nSkipping line 512494: expected 6 fields, saw 8\nSkipping line 512516: expected 6 fields, saw 8\nSkipping line 512837: expected 6 fields, saw 8\nSkipping line 512984: expected 6 fields, saw 8\nSkipping line 514403: expected 6 fields, saw 7\nSkipp ...
# b'Skipping line 524529: expected 6 fields, saw 7\nSkipping line 524990: expected 6 fields, saw 7\n'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529025 entries, 0 to 529024
# Data columns (total 6 columns):
# date     529025 non-null object
# url      529025 non-null object
# host     529025 non-null object
# topic    529025 non-null object
# title    529025 non-null object
# body     529025 non-null object
# dtypes: object(6)
# memory usage: 24.2+ MB

# %%
data["cleaned_text"] = data["body"].apply(preprocessing_tools.clean_text)
data[["cleaned_text"]].head()
# Out:
#                                         cleaned_text
# 0  барнаул  февраля interfaxru  первый городской ...
# 1  чита  февраля interfaxru  эксглава нк \юкос\ м...
# 2  москва  февраля interfaxru  в результате пожар...
# 3  токио  февраля interfaxru  рост ввп россии в  ...
# 4  москва  февраля interfaxru  цены на нефть выро...

# %%
texts = data["cleaned_text"].tolist()
texts = [re.sub(r'\\', '', x) for x in texts]

data["cleaned_text"] = data["cleaned_text"].apply(lambda x: re.sub(r'\\', '', x))
data[["cleaned_text"]].head()
# Out:
#                                         cleaned_text
# 0  барнаул  февраля interfaxru  первый городской ...
# 1  чита  февраля interfaxru  эксглава нк юкос мих...
# 2  москва  февраля interfaxru  в результате пожар...
# 3  токио  февраля interfaxru  рост ввп россии в  ...
# 4  москва  февраля interfaxru  цены на нефть выро...

# %%
stopword_ru = stopwords.words('russian')
data["tokenized_text"] = data["cleaned_text"].apply(preprocessing_tools.lemmatization, stopword=stopword_ru)
data[["tokenized_text"]].head()
# Out:
#                                       tokenized_text
# 0  [барнаул, февраль, interfaxru, городской, чемп...
# 1  [чита, февраль, interfaxru, эксглава, нк, юкос...
# 2  [москва, февраль, interfaxru, результат, пожар...
# 3  [токио, февраль, interfaxru, рост, ввп, россия...
# 4  [москва, февраль, interfaxru, цена, нефть, выр...

# %%
tockens_clean = data["tokenized_text"].tolist()
texts_clean = [" ".join(x) for x in tockens_clean]

# %% [raw]
# import gc
# del data
# gc.collect()

# %%
vectorizer = CountVectorizer(analyzer='word', max_features=3000);
x_counts = vectorizer.fit_transform(texts_clean);
print(x_counts.shape)
# Out:
# (529025, 3000)

# %%
transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
#obtain a NMF model.
num_topics = 200
model = NMF(n_components=num_topics, init='nndsvd');

#fit the model
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=200, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
topic_model = get_nmf_topics(model, 20)

# %%
topic_model
# Out:
#           Topic # 01       Topic # 02  Topic # 03   Topic # 04    Topic # 05  \
# 0          журналист        произойти       рубль         матч       адвокат
# 1            сказать         инцидент   стоимость          тур         арест
# 2            заявить           авария   составить      спартак     обвинение
# 3           сообщить       пострадать      размер         цска        бывший
# 4              песок       возгорание    триллион      стадион     следствие
# 5   пресссекретарить          причина       сумма        зенит      обвинять
# 6         interfaxru  предварительный        днём           го    предъявить
# 7        вицепремьер     происшествие  составлять       минута        стража
# 8                сми   обстоятельство       штраф       футбол   ходатайство
# 9              слово           данные       доход    болельщик    пресечение
# 10          отвечать        обрушение     вырасти  премьерлига          дело
# 11             игорь            шахта    денежный         игра  ходорковский
# 12                иф            около    средство    локомотив      фигурант
# 13          добавить            драка       ущерб   футбольный          мера
# 14       планировать            никто    похитить         очки      домашний
# 15            москва  устанавливаться       образ          гол        защита
# 16           дмитрий              изз    выразить          пол          юкос
# 17       заместитель        результат     выплата    чемпионат     мосгорсуд
# 18            андрей         трагедия  предыдущий      сыграть       лебедев
# 19           сегодня            утром   сравнение        рубин          срок
#
#        Topic # 06    Topic # 07   Topic # 08       Topic # 09  \
# 0           пожар       самолёт       индекс           япония
# 1      возгорание       посадка         ммвб         японский
# 2        пожарный          борт        пункт           остров
# 3   ликвидировать         полёт          ртс              аэс
# 4         тушение         пилот        рынок             вода
# 5           огонь      крушение     фондовый             иена
# 6          лесной     воздушный         торг             река
# 7          гореть            ан        биржа          уровень
# 8              кв     разбиться          мск           авария
# 9      возникнуть      вылететь      вырасти              вод
# 10          склад           ввс          фон          атомный
# 11           метр   истребитель  большинство        побережье
# 12             га    катастрофа       упасть              изз
# 13           этаж     совершить     рублёвый            океан
# 14     квадратный   авиационный       бумага            берег
# 15      сложность  авиакомпания     площадка  территориальный
# 16        причина      аэродром       предел            визит
# 17        единица        лайнер        акция        сантиметр
# 18             гу     двигатель      мировой              мор
# 19        техника  пассажирский    открыться        аварийный
#
#          Topic # 10       ...         Topic # 90      Topic # 91  \
# 0              край       ...           вертолёт     космический
# 1     краснодарский       ...                 ми         аппарат
# 2          пермский       ...           крушение         спутник
# 3      красноярский       ...            посадка       космодром
# 4             пермь       ...               борт          орбита
# 5           краевой       ...              пилот          запуск
# 6       хабаровский       ...              поиск            блок
# 7        губернатор       ...          спасатель        байконур
# 8         краснодар       ...          разбиться       роскосмос
# 9        приморский       ...         катастрофа         вывести
# 10       камчатский       ...             упасть       запустить
# 11               га       ...            жёсткий  интерфаксуавна
# 12           лесной       ...          воздушный           земля
# 13    администрация       ...              полёт            пуск
# 14             сочи       ...            падение           связь
# 15         приморье       ...           пропасть           старт
# 16  интерфакссибирь       ...          совершить      стартовать
# 17          посёлок       ...             экипаж         целевой
# 18        хабаровск       ...        авиационный         отрасль
# 19             река       ...           километр      назначение
#
#        Topic # 92     Topic # 93  Topic # 94    Topic # 95       Topic # 96  \
# 0          осетия         ноябрь      январь       полиция          решение
# 1           южный         москва      москва   полицейский          принять
# 2         абхазия     interfaxru  interfaxru         отдел    окончательный
# 3      грузинский          месяц  новогодний       местный            связь
# 4        северный             мх   австралия      стрельба         комиссия
# 5   независимость          конец          ск     столичный         принятие
# 6          эдуард         начало        снег       порядок             мера
# 7       признание     состояться       месяц        главка           власть
# 8         граница           марш    открытый     доставить         отменить
# 9        конфликт       объявить  домодедово          умвд       обжаловать
# 10             лр           дата       минус    арестовать  соответствующий
# 11          поток       итоговый     транзит      инцидент   процессуальный
# 12        сторона          образ        сбор   подозревать      руководство
# 13       закрытый       середина    праздник     несколько           решить
# 14    наблюдатель          париж        ночь            гу         проблема
# 15          корея         казань   составить       прибыть            отказ
# 16           село       послание   казахстан     отделение         объявить
# 17             вб      перенести   перенести    беспорядок    приостановить
# 18             мх             го       тариф    задержание      приниматься
# 19    интерфаксюг  информировать  сообщаться  происшествие           жалоба
#
#       Topic # 97        Topic # 98      Topic # 99
# 0          место           декабрь   правительство
# 1         занять            москва  премьерминистр
# 2   происшествие        interfaxru     вицепремьер
# 3        рейтинг        новогодний       заседание
# 4         третье             пермь        киргизия
# 5       занимать          пермский    распоряжение
# 6           балл                ск         кабинет
# 7           очки             конец         премьер
# 8         первое        состояться   постановление
# 9       работать  прессконференция       временной
# 10       набрать                мх    председатель
# 11       прибыть          объявить        отставка
# 12       выехать              снег           новое
# 13      пожарный                ii        поручить
# 14     подняться              дата     предложение
# 15        четыре            начало        премьера
# 16        второе         перенести    сформировать
# 17           тур          праздник       парламент
# 18       позиция          послание       утвердить
# 19    лидировать            вокзал       совещание
#
# [20 rows x 200 columns]
