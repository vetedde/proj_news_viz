# %% [markdown]
# # Dynamic topic modelling via Non-negative Matrix Factorization (NMF)

# %% [markdown]
# Warning: running the whole notebook requires more than 16Gb RAM.
# However you can run steps 1 and 2 separately

# %%
! pip3 install gensim
! pip3 install razdel
! pip3 install pymorphy2

# %% [markdown]
# Import some preprocessing tools

# %%
import sys
sys.path.insert(0, '../../../preprocessing')
import preprocessing_tools_updt as preprocessing_tools

# %%
import pandas as pd;
import numpy as np;
import scipy as sp;
import sklearn;
import sys;
from nltk.corpus import stopwords;
import nltk;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
import re;
from io import StringIO;
from nltk.corpus import stopwords
import gc

# %%
# data_file = "~/Projects/project_news/proj_news_viz/interfax_sorted_2008-02-11_2019-01-19.csv"
data_file = "~/Downloads/topic_news/topici_i_rubrici_go.csv"

# %% [markdown]
# # Step 1: Preprocessing

# %% [markdown]
# Here we will process input .csv line by line as far as the separator "|" happens to be a part of the message body for some entries

# %%
date  = []
url   = []
host  = []
topic = []
title = []
body  = []
with open('../../../../../../project_news/interfax_sorted_2008-02-11_2019-01-19.csv') as news_file:
    for line in news_file:
        fields = line.split("|")
        date.append(fields[0])
        url.append(fields[1])
        host.append(fields[2])
        topic.append(fields[3])
        title.append(fields[4])
        body.append(" ".join(fields[5:]))
    news_file.close()
data_prep = pd.DataFrame({'date' : date,
                          'url'  : url,
                          'host' : host,
                          'topic': topic,
                          'title': title,
                          'body' : body},
                         columns={'date', 'url', 'host', 'topic', 'title', 'body'})
data_prep.info()

# %%
data = pd.read_csv(data_file,
                   sep=',',
                   encoding='utf-8',
                   error_bad_lines=False);
# data.columns = ["date", "url", "host", "topic", "title", "body"]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235915 entries, 0 to 235914
# Data columns (total 5 columns):
# short_topic     235915 non-null object
# short_rubric    235915 non-null object
# newtext         235915 non-null object
# year_text       235915 non-null object
# topic_rubric    235915 non-null object
# dtypes: object(5)
# memory usage: 9.0+ MB

# %% [markdown]
# As we can see, 106 entries are lost due to extra separators. However, I assume, it is not critical.

# %%
data.head()
# Out:
#   short_topic    short_rubric  \
# 0  Библиотека  Первая мировая
# 1  Библиотека  Первая мировая
# 2  Библиотека  Первая мировая
# 3  Библиотека  Первая мировая
# 4  Библиотека  Первая мировая
#
#                                              newtext  \
# 0  бой сопоцкина друскеник закончиться отступлени...
# 1  министерство народный просвещение вид происход...
# 2  фотограф-корреспондент daily mirror рассказыва...
# 3  штабс-капитан п н нестер день увидеть район же...
# 4  лицо приехать варшава люблин передавать туда д...
#
#                                            year_text  \
# 0  1914-09 бой сопоцкина друскеник закончиться от...
# 1  1914-09 министерство народный просвещение вид ...
# 2  1914-09 фотограф-корреспондент daily mirror ра...
# 3  1914-09 штабс-капитан п н нестер день увидеть ...
# 4  1914-09 лицо приехать варшава люблин передават...
#
#                 topic_rubric
# 0  Библиотека/Первая мировая
# 1  Библиотека/Первая мировая
# 2  Библиотека/Первая мировая
# 3  Библиотека/Первая мировая
# 4  Библиотека/Первая мировая

# %%
from datetime import datetime
data["date"] = data["year_text"].apply(lambda x: datetime.strptime(x.split(" ")[0], '%Y-%M'))

# %%
data["date"].head(20)
# Out:
# 0    1914-01-01 00:09:00
# 1    1914-01-01 00:09:00
# 2    1914-01-01 00:09:00
# 3    1914-01-01 00:09:00
# 4    1914-01-01 00:09:00
# 5    2004-01-01 00:05:00
# 6    2008-01-01 00:04:00
# 7    2009-01-01 00:03:00
# 8    2009-01-01 00:11:00
# 9    2010-01-01 00:11:00
# 10   2011-01-01 00:06:00
# 11   2012-01-01 00:11:00
# 12   2012-01-01 00:11:00
# 13   2012-01-01 00:03:00
# 14   2012-01-01 00:05:00
# 15   2012-01-01 00:12:00
# 16   2012-01-01 00:12:00
# 17   2012-01-01 00:09:00
# 18   2013-01-01 00:12:00
# 19   2013-01-01 00:12:00
# Name: date, dtype: datetime64[ns]

# %%
del data_prep
del date
del url
del host
del topic
del title
del body
gc.collect()

# %%
data["cleaned_text"] = data["body"].apply(preprocessing_tools.clean_text)
data[["cleaned_text"]].head()

# %%
# stopword_ru = stopwords.words('russian')
stopword_ru = "../../../preprocessing/stopwords.txt"
data["tokenized_text"] = data["cleaned_text"].apply(preprocessing_tools.lemmatization, stopword=stopword_ru)
data[["tokenized_text"]].head()

# %% [markdown]
# NMF expects input texts as strings

# %%
tockens_clean = data["tokenized_text"].tolist()
texts_clean = [" ".join(x) for x in tockens_clean]

# %%
del data
gc.collect()

# %% [markdown]
# Save preprocessed texts into a file

# %%
with open('./clean.texts.txt', 'wt') as out_file:
    for doc in texts_clean:
        out_file.write(doc + '\n')
    out_file.close()

# %% [markdown]
# # Step 2: Topic modelling

# %% [markdown]
# Now we will read the preprocessed data

# %%
documents = []
with open('clean.texts.txt', 'rt') as in_file:
    for line in in_file:
        documents.append(line.rstrip())
    in_file.close()

# %%
documents[0]

# %%
max_features = 3000
vectorizer = CountVectorizer(analyzer='word', max_features=max_features);
x_counts = vectorizer.fit_transform(documents);
print(x_counts.shape)

# %%
transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %% [markdown]
# Let us decompose the document-term matrix and experiment with the number of topics

# %% [markdown]
# 200 topics

# %%
num_topics = 200
model = NMF(n_components=num_topics, init='nndsvd');
model.fit(xtfidf_norm)

# %%
# https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
topics = get_nmf_topics(model, 20)
topics

# %% [markdown]
# While some topics are pretty clear:
# Topic #1 - что-то связанное с передачей информации
# Topic #2 - происшествия, несчастные случаи
# Topic #3 - финансы, валюта
# Topic #4 - футбол
# Topic #5 - судебные дела
# Topic #6 - пожары
# Topic #7 - инциденты с авиационной техникой
# ...
#
# Nevertheless, some topics overlap (like 7 and 90)

# %%
topics.to_csv('../nmf.topics.%d.csv' % num_topics)

# %% [markdown]
# 400 topics

# %%
num_topics = 400
model = NMF(n_components=num_topics, init='nndsvd');
model.fit(xtfidf_norm)

# %%
topics400 = get_nmf_topics(model, 20)
topics400

# %% [markdown]
# Now let's try to extract topics from lenta.ru preprocessed corpus

# %%
documents = data["newtext"]
documents[:3]
# Out:
# 0    бой сопоцкина друскеник закончиться отступлени...
# 1    министерство народный просвещение вид происход...
# 2    фотограф-корреспондент daily mirror рассказыва...
# Name: newtext, dtype: object

# %%
max_features = 3000
vectorizer = CountVectorizer(analyzer='word', max_features=max_features);
x_counts = vectorizer.fit_transform(documents);
print(x_counts.shape)
# Out:
# (235915, 3000)

# %%
transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
num_topics = 400
model = NMF(n_components=num_topics, init='nndsvd');
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=400, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
import pickle
filename = './nmf.lentaru.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
topics = get_nmf_topics(model, 20)
topics
# Out:
#    Topic # 01      Topic # 02   Topic # 03       Topic # 04     Topic # 05  \
# 0         год         команда     миллиард          украина       зарплата
# 1        2013         сборная      объесть           гривна       работник
# 2        2014    национальный        сумма        верховный           труд
# 3        2012       чемпионат       резерв              сбу          доход
# 4        2015           игрок        общий              рад       получать
# 5        2011         капитан      капитал           яценюк        средний
# 6        2010       выступать    составить             рада        уровень
# 7        2009           пилот      выручка         украинец        рабочий
# 8   последний          играть       чистый              112        выплата
# 9        2008         партнёр    состояние          арсений          плата
# 10       2007        выиграть      прибыль              мвф       реальный
# 11         ха       поражение        актив          заявить         оплата
# 12    прошлое       следующий  оцениваться           восток      население
# 13       2006      первенство     выделить         ситуация         размер
# 14    возраст     официальный       убыток           одесса          месяц
# 15       2005  присоединиться   инвестиция  государственный     составлять
# 16        это        домашний      богатый        гражданин      повышение
# 17      назад      продолжить        объём            режим  задолженность
# 18     начало            сбор      крупный          реформа    минимальный
# 19       2000       проиграть       гривна  территориальный      космодром
#
#       Topic # 06   Topic # 07    Topic # 08          Topic # 09  \
# 0          фильм    коллекция     погибнуть               видео
# 1         прокат  представить           ещё         публиковать
# 2          лента      линейка      погибший             youtube
# 3          оскар        войти       ранение               снять
# 4       премьера    украшение          двое                кадр
# 5      кинотеатр    выпустить          трое        опубликовать
# 6       сценарий        марка        данные              снятой
# 7           кино        линия     провинция         запечатлеть
# 8         съёмка    аксессуар        гибель            выложить
# 9          экран    посвятить        четыре          разместить
# 10         показ    поступить        жертва            показать
# 11  рассказывать       золото       раненый               видно
# 12         герой      предмет          пять            просмотр
# 13        снятой       кольцо       reuters             снимать
# 14       собрать          нея      крушение            очевидец
# 15       сняться        релиз       меньший             событие
# 16         сюжет    выполнить     произойти         представить
# 17        джеймс     редакция       четверо     демонстрировать
# 18      показать        стиль     разбиться  продемонстрировать
# 19          сбор        также  столкновение             попасть
#
#            Topic # 10  ...    Topic # 391   Topic # 392      Topic # 393  \
# 0             процент  ...        газпром      внимание           смерть
# 1               опрос  ...       контракт      обратить       скончаться
# 2          респондент  ...        газовый      привлечь          умереть
# 3            опросить  ...        концерн        блогер          причина
# 4                доля  ...        холдинг      проблема          возраст
# 5            инфляция  ...      правление      заметить              год
# 6             вырасти  ...     газопровод     необычный         родиться
# 7               голос  ...        алексей        портал          болезнь
# 8        исследование  ...          штраф     некоторый           сердце
# 9           снизиться  ...        решение        особый              рак
# 10         показатель  ...  месторождение      отметить      заболевание
# 11             данные  ...       медведев           сми           гибель
# 12           согласно  ...   председатель       зритель          повлечь
# 13            считать  ...          поток      пытаться        известный
# 14  свидетельствовать  ...          рынок         автор   обстоятельство
# 15        увеличиться  ...      положение  предположить      родственник
# 16           половина  ...    арбитражный         шутка        последний
# 17             индекс  ...       компания     выглядеть  предварительный
# 18         составлять  ...        обязать     поведение         потерять
# 19             упасть  ...          нефть   комментарий           старый
#
#         Topic # 394      Topic # 395         Topic # 396      Topic # 397  \
# 0           граница         интернет               обувь             флаг
# 1             пункт           доступ                кожа          красный
# 2       пограничник               ru               сумка  государственный
# 3       пограничный           ресурс           аксессуар      изображение
# 4          населить           онлайн            основать           символ
# 5         гражданин           портал               цвета             цвет
# 6   государственный          контент           выполнить            цвета
# 7          контроль      электронный              модный            судно
# 8         российско  распространение  специализироваться       изобразить
# 9        таможенный              com          спортивный            белый
# 10             зона   информационный             изделие            форма
# 11         пытаться            товар                цвет             знак
# 12              фсб     пользоваться           выпустить          надпись
# 13          паспорт       блокировка              дизайн        советский
# 14          мексика             2013             красный        церемония
# 15            въезд         площадка        производство             порт
# 16             груз       бесплатный                пара     национальный
# 17     гуманитарный          сегмент         представить           судный
# 18           индекс         выложить           настоящее          зелёный
# 19       незаконный          покупка         производить              фон
#
#        Topic # 398    Topic # 399  Topic # 400
# 0          создать    неизвестный       газета
# 1     использовать       похитить       писать
# 2         создание          кража  коммерсантъ
# 3       технология        украсть    ведомость
# 4         материал  злоумышленник     известие
# 5    использование   преступление        times
# 6           основа     преступник     редактор
# 7   использоваться       скрыться       ссылка
# 8      специальный    подозревать          сми
# 9       разработка      похищение     материал
# 10        качество          сумка          new
# 11     разработать      совершить         york
# 12       позволять          ущерб   публикация
# 13            база          маска     источник
# 14       создавать          хакер         post
# 15       способный           двое       статья
# 16           метод    потерпевший          рбк
# 17            идея        забрать      холдинг
# 18            цель        удаться       данные
# 19   искусственный      стоимость        номер
#
# [20 rows x 400 columns]

# %%
topics.head(30)
# Out:
#    Topic # 01      Topic # 02   Topic # 03       Topic # 04     Topic # 05  \
# 0         год         команда     миллиард          украина       зарплата
# 1        2013         сборная      объесть           гривна       работник
# 2        2014    национальный        сумма        верховный           труд
# 3        2012       чемпионат       резерв              сбу          доход
# 4        2015           игрок        общий              рад       получать
# 5        2011         капитан      капитал           яценюк        средний
# 6        2010       выступать    составить             рада        уровень
# 7        2009           пилот      выручка         украинец        рабочий
# 8   последний          играть       чистый              112        выплата
# 9        2008         партнёр    состояние          арсений          плата
# 10       2007        выиграть      прибыль              мвф       реальный
# 11         ха       поражение        актив          заявить         оплата
# 12    прошлое       следующий  оцениваться           восток      население
# 13       2006      первенство     выделить         ситуация         размер
# 14    возраст     официальный       убыток           одесса          месяц
# 15       2005  присоединиться   инвестиция  государственный     составлять
# 16        это        домашний      богатый        гражданин      повышение
# 17      назад      продолжить        объём            режим  задолженность
# 18     начало            сбор      крупный          реформа    минимальный
# 19       2000       проиграть       гривна  территориальный      космодром
#
#       Topic # 06   Topic # 07    Topic # 08          Topic # 09  \
# 0          фильм    коллекция     погибнуть               видео
# 1         прокат  представить           ещё         публиковать
# 2          лента      линейка      погибший             youtube
# 3          оскар        войти       ранение               снять
# 4       премьера    украшение          двое                кадр
# 5      кинотеатр    выпустить          трое        опубликовать
# 6       сценарий        марка        данные              снятой
# 7           кино        линия     провинция         запечатлеть
# 8         съёмка    аксессуар        гибель            выложить
# 9          экран    посвятить        четыре          разместить
# 10         показ    поступить        жертва            показать
# 11  рассказывать       золото       раненый               видно
# 12         герой      предмет          пять            просмотр
# 13        снятой       кольцо       reuters             снимать
# 14       собрать          нея      крушение            очевидец
# 15       сняться        релиз       меньший             событие
# 16         сюжет    выполнить     произойти         представить
# 17        джеймс     редакция       четверо     демонстрировать
# 18      показать        стиль     разбиться  продемонстрировать
# 19          сбор        также  столкновение             попасть
#
#            Topic # 10  ...    Topic # 391   Topic # 392      Topic # 393  \
# 0             процент  ...        газпром      внимание           смерть
# 1               опрос  ...       контракт      обратить       скончаться
# 2          респондент  ...        газовый      привлечь          умереть
# 3            опросить  ...        концерн        блогер          причина
# 4                доля  ...        холдинг      проблема          возраст
# 5            инфляция  ...      правление      заметить              год
# 6             вырасти  ...     газопровод     необычный         родиться
# 7               голос  ...        алексей        портал          болезнь
# 8        исследование  ...          штраф     некоторый           сердце
# 9           снизиться  ...        решение        особый              рак
# 10         показатель  ...  месторождение      отметить      заболевание
# 11             данные  ...       медведев           сми           гибель
# 12           согласно  ...   председатель       зритель          повлечь
# 13            считать  ...          поток      пытаться        известный
# 14  свидетельствовать  ...          рынок         автор   обстоятельство
# 15        увеличиться  ...      положение  предположить      родственник
# 16           половина  ...    арбитражный         шутка        последний
# 17             индекс  ...       компания     выглядеть  предварительный
# 18         составлять  ...        обязать     поведение         потерять
# 19             упасть  ...          нефть   комментарий           старый
#
#         Topic # 394      Topic # 395         Topic # 396      Topic # 397  \
# 0           граница         интернет               обувь             флаг
# 1             пункт           доступ                кожа          красный
# 2       пограничник               ru               сумка  государственный
# 3       пограничный           ресурс           аксессуар      изображение
# 4          населить           онлайн            основать           символ
# 5         гражданин           портал               цвета             цвет
# 6   государственный          контент           выполнить            цвета
# 7          контроль      электронный              модный            судно
# 8         российско  распространение  специализироваться       изобразить
# 9        таможенный              com          спортивный            белый
# 10             зона   информационный             изделие            форма
# 11         пытаться            товар                цвет             знак
# 12              фсб     пользоваться           выпустить          надпись
# 13          паспорт       блокировка              дизайн        советский
# 14          мексика             2013             красный        церемония
# 15            въезд         площадка        производство             порт
# 16             груз       бесплатный                пара     национальный
# 17     гуманитарный          сегмент         представить           судный
# 18           индекс         выложить           настоящее          зелёный
# 19       незаконный          покупка         производить              фон
#
#        Topic # 398    Topic # 399  Topic # 400
# 0          создать    неизвестный       газета
# 1     использовать       похитить       писать
# 2         создание          кража  коммерсантъ
# 3       технология        украсть    ведомость
# 4         материал  злоумышленник     известие
# 5    использование   преступление        times
# 6           основа     преступник     редактор
# 7   использоваться       скрыться       ссылка
# 8      специальный    подозревать          сми
# 9       разработка      похищение     материал
# 10        качество          сумка          new
# 11     разработать      совершить         york
# 12       позволять          ущерб   публикация
# 13            база          маска     источник
# 14       создавать          хакер         post
# 15       способный           двое       статья
# 16           метод    потерпевший          рбк
# 17            идея        забрать      холдинг
# 18            цель        удаться       данные
# 19   искусственный      стоимость        номер
#
# [20 rows x 400 columns]

# %%
res = model.transform(xtfidf_norm)

# %%
feature_names = vectorizer.get_feature_names()

# %%
print(res.shape)
len(feature_names)
model.components_.shape
# Out:
# (235915, 400)
# (400, 3000)

# %%
dt = pd.DataFrame(res)
dt.columns = ["Topic_%d" % i for i in range(1, 401)]
dt["date"] = data["date"]
dt.reset_index(inplace=True)
dt.head()
# Out:
#    index   Topic_1   Topic_2  Topic_3  Topic_4  Topic_5   Topic_6  Topic_7  \
# 0      0  0.002590  0.000000      0.0      0.0      0.0  0.000000      0.0
# 1      1  0.010208  0.000000      0.0      0.0      0.0  0.000006      0.0
# 2      2  0.002994  0.000000      0.0      0.0      0.0  0.000018      0.0
# 3      3  0.004738  0.000330      0.0      0.0      0.0  0.000012      0.0
# 4      4  0.003027  0.000964      0.0      0.0      0.0  0.000013      0.0
#
#     Topic_8   Topic_9  ...  Topic_392  Topic_393  Topic_394  Topic_395  \
# 0  0.000000  0.000000  ...   0.000152   0.000000    0.00015   0.000003
# 1  0.000000  0.000762  ...   0.000000   0.000000    0.00000   0.000000
# 2  0.000000  0.000000  ...   0.000000   0.000000    0.00000   0.000000
# 3  0.011757  0.000000  ...   0.000000   0.005701    0.00000   0.000000
# 4  0.000000  0.000000  ...   0.000000   0.000000    0.00000   0.000000
#
#    Topic_396  Topic_397  Topic_398  Topic_399  Topic_400                date
# 0        0.0   0.000000   0.000046   0.000000        0.0 1914-01-01 00:09:00
# 1        0.0   0.000000   0.000000   0.000167        0.0 1914-01-01 00:09:00
# 2        0.0   0.000000   0.000000   0.000000        0.0 1914-01-01 00:09:00
# 3        0.0   0.000000   0.000000   0.000000        0.0 1914-01-01 00:09:00
# 4        0.0   0.000674   0.000000   0.001765        0.0 1914-01-01 00:09:00
#
# [5 rows x 402 columns]

# %%
dt_melt = dt.melt('date', var_name='topic', value_name='text')
print(dt_melt.shape)
dt_melt.head()
# Out:
# (94601915, 3)
#                  date  topic  text
# 0 1914-01-01 00:09:00  index   0.0
# 1 1914-01-01 00:09:00  index   1.0
# 2 1914-01-01 00:09:00  index   2.0
# 3 1914-01-01 00:09:00  index   3.0
# 4 1914-01-01 00:09:00  index   4.0

# %%
joined_melt_new = dt_melt[(dt_melt.topic!='index') & (dt_melt.topic!='date')]
print(joined_melt_new.shape)
joined_melt_new.topic.value_counts()
# Out:
# (94366000, 3)
# Topic_199    235915
# Topic_201    235915
# Topic_336    235915
# Topic_344    235915
# Topic_350    235915
# Topic_397    235915
# Topic_188    235915
# Topic_235    235915
# Topic_361    235915
# Topic_5      235915
# Topic_225    235915
# Topic_37     235915
# Topic_140    235915
# Topic_218    235915
# Topic_275    235915
# Topic_261    235915
# Topic_145    235915
# Topic_81     235915
# Topic_227    235915
# Topic_179    235915
# Topic_256    235915
# Topic_115    235915
# Topic_2      235915
# Topic_216    235915
# Topic_124    235915
# Topic_130    235915
# Topic_209    235915
# Topic_346    235915
# Topic_26     235915
# Topic_393    235915
#               ...
# Topic_77     235915
# Topic_165    235915
# Topic_22     235915
# Topic_99     235915
# Topic_146    235915
# Topic_366    235915
# Topic_132    235915
# Topic_396    235915
# Topic_23     235915
# Topic_370    235915
# Topic_312    235915
# Topic_104    235915
# Topic_247    235915
# Topic_144    235915
# Topic_381    235915
# Topic_24     235915
# Topic_129    235915
# Topic_70     235915
# Topic_45     235915
# Topic_222    235915
# Topic_116    235915
# Topic_29     235915
# Topic_42     235915
# Topic_160    235915
# Topic_86     235915
# Topic_200    235915
# Topic_40     235915
# Topic_121    235915
# Topic_38     235915
# Topic_177    235915
# Name: topic, Length: 400, dtype: int64

# %%
def display_topics(H, W, feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]]) for i in topic.argsort()[:-no_top_words - 1:-1])
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print(documents[doc_index])

# %%
display_topics(model.components_, res.T, feature_names, documents, 20, 4)
# Out:
# Topic 0:
# <generator object display_topics.<locals>.<genexpr> at 0x125d6bb88>
# премьер-министр рф дмитрий медведев утвердить состав совет русский язык правительство россия соответствующий распоряжение 1 декабрь разместить сайт правительство совет возглавить вице-премьер ольга голодец заместитель стать министр образование дмитрий ливан помимо орган войти ещё 33 человек число который представитель сми образовательный культурный организация также федеральный региональный чиновник совет русский язык утвердить постановление правительство 5 ноябрь 2013 год задача входить обеспечение государственный поддержка развитие язык также содействие изучение распространение 21 ноябрь президент рф владимир путин выступать российский литературный собрание выразить обеспокоенность общий снижение грамотность пренебрежение правило русский язык это отметить русский язык слишком велик традиция разрушить
# европейский вещательный компания евк ретранслировать россия программа телеканал euronews намерить провести делистинг свой акция московский биржа акционер евк рассмотреть вопрос собрание 19 декабрь писать номер 3 декабрь газета коммерсантъ размещение евк провести апрель 2012 год продать биржа около процент акция 30 тысяча ценный бумага стоимость десять копейка каждый однако последний сделка пройти весной это год 15 апрель транзакция бумага евк произойти евк являться структура вгтрк основной актив последний — федеральный телеканал россия 1 россия 2 россия итог 2012 год чистый прибыль евк составить 16 миллион рубль выручка 147 миллион рубль пресс-служба вгтрк отказаться комментировать уход евк биржа московский биржа торговаться акция медиахолдинг головной компания кабельный канал 2 тв американский биржа nasdaq проходить торг ценный бумага холдинг стс медиа управлять телеканал стс домашний перец
# хоккейный клуб питтсбург пингвинс матч регулярный чемпионат национальный хоккейный лига обыграть флорида пантерс счёт 5 1 сообщать официальный сайт нхл хороший игрок матч признанный россиянин евгений малкин записать свой счёт забитый шайба результативный передача список хороший бомбардир лига малкин занимать место 35 очки очко отставать капитан пингвинс сидень кросби друг матч игровой день встречаться вашингтон кэпиталс нью-йорк айлендерс встреча завершиться победа столичный клуб счёт 3 2 победный шайба овертайм забить капитан вашингтон александр овечкин признанный звезда встреча благодаря забитый шайба овечкин упрочить свой лидерство таблица хороший снайпер нхл 21 голый
# Topic 257:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Extract dominant topics for each document

# %%
doc_topic = pd.DataFrame({'date':data["date"],
                          'topic':res.argmax(axis=1),
                          'body':documents},
                  columns=['date', 'topic', 'body'])

# %%
doc_topic.to_csv('./nmf.lentaru.dominant_topics.%d.csv' % num_topics)

# %%
doc_topic.head(30)
# Out:
#                   date  topic  \
# 0  1914-01-01 00:09:00     27
# 1  1914-01-01 00:09:00    135
# 2  1914-01-01 00:09:00    128
# 3  1914-01-01 00:09:00    234
# 4  1914-01-01 00:09:00    382
# 5  2004-01-01 00:05:00    399
# 6  2008-01-01 00:04:00     28
# 7  2009-01-01 00:03:00     85
# 8  2009-01-01 00:11:00     21
# 9  2010-01-01 00:11:00     30
# 10 2011-01-01 00:06:00    210
# 11 2012-01-01 00:11:00     38
# 12 2012-01-01 00:11:00     28
# 13 2012-01-01 00:03:00     44
# 14 2012-01-01 00:05:00     38
# 15 2012-01-01 00:12:00     25
# 16 2012-01-01 00:12:00     27
# 17 2012-01-01 00:09:00     37
# 18 2013-01-01 00:12:00      3
# 19 2013-01-01 00:12:00      3
# 20 2013-01-01 00:12:00     11
# 21 2013-01-01 00:12:00     38
# 22 2013-01-01 00:12:00     91
# 23 2013-01-01 00:12:00      3
# 24 2013-01-01 00:12:00     22
# 25 2013-01-01 00:12:00     47
# 26 2013-01-01 00:12:00      3
# 27 2013-01-01 00:12:00    130
# 28 2013-01-01 00:12:00      3
# 29 2013-01-01 00:12:00    378
#
#                                                  body
# 0   бой сопоцкина друскеник закончиться отступлени...
# 1   министерство народный просвещение вид происход...
# 2   фотограф-корреспондент daily mirror рассказыва...
# 3   штабс-капитан п н нестер день увидеть район же...
# 4   лицо приехать варшава люблин передавать туда д...
# 5   россия мочь компенсировать эстония ущерб нанес...
# 6   американский актёр уэсли снайпёс четверг приго...
# 7   нью-йорк арестовать подозревать убийство радио...
# 8   власть район столица южный корея запустить про...
# 9   город портленд штат орегон вечером 26 ноябрь а...
# 10  трасса канада произойти дтп участие медведь со...
# 11  вечером 26 ноябрь 2012 год москва хельсинки ко...
# 12  убийца отбывать наказание великобритания пожал...
# 13  понедельник 12 март начаться этап создание вел...
# 14  федеральный пассажирский компания входящая сос...
# 15  житель флорида джордж циммерман обвинять убийс...
# 16  махачкала четверг 27 декабрь задержать лидер д...
# 17  компания револьта получить разрешение импорт п...
# 18  сторонник евроинтеграция украина вернуться май...
# 19  боец спецподразделение беркут жёстко оттеснить...
# 20  живой журнал целое ряд авторитетный блогер инт...
# 21  причина крушение поезд нью-йорк стать отказ то...
# 22  космический аппарат чанъэ-3 борт который наход...
# 23  окружный административный суд киев удовлетвори...
# 24  грозненский терек питерский зенит сыграть внич...
# 25  результат возгорание склад восток москва погиб...
# 26  украинский делегация следующий неделя отправит...
# 27  премьер-министр рф дмитрий медведев утвердить ...
# 28  ход уличный столкновение центр киев пострадать...
# 29  индийский марсианский зонд мангальяна воскресе...

# %% [markdown]
# # Joypy

# %%
import joypy # !pip install joypy

# %%
doc_topic.melt()

# %%
labels = sorted(joined_melt_new['date'].unique())

fig, axes = joypy.joyplot(joined_melt_new, by='topic', column='text', figsize=(20, 10),xlabelsize=20,ylabelsize=20,
                          overlap=0.4, fill=True, linecolor="k", linewidth=2,
                          kind='values', fade=True, xrot=90, x_range=[i for i in range(len(labels))],
                          background='white');

ticks_labels = {i:t for i, t in enumerate(labels)}
axes[-1].set_xticks([k for k, v in ticks_labels.items() if k % 6 == 0])
ticks = axes[-1].get_xticks()
axes[-1].set_xticklabels([ticks_labels.get(i, 'stop') for i in ticks]);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-a95bb3505031> in <module>
#       4                           overlap=0.4, fill=True, linecolor="k", linewidth=2,
#       5                           kind='values', fade=True, xrot=90, x_range=[i for i in range(len(labels))],
# ----> 6                           background='white');
#       7
#       8 ticks_labels = {i:t for i, t in enumerate(labels)}
#
# /usr/local/lib/python3.7/site-packages/joypy/joyplot.py in joyplot(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, figsize, hist, bins, fade, ylim, fill, linecolor, overlap, background, labels, xlabels, ylabels, range_style, x_range, title, colormap, **kwds)
#     235                     title=title,
#     236                     colormap=colormap,
# --> 237                     **kwds)
#     238
#     239 ###########################################
#
# /usr/local/lib/python3.7/site-packages/joypy/joyplot.py in _joyplot(data, grid, labels, sublabels, xlabels, xlabelsize, xrot, ylabelsize, yrot, ax, figsize, hist, bins, fade, xlim, ylim, fill, linecolor, overlap, background, range_style, x_range, tails, title, legend, loc, colormap, color, **kwargs)
#     436                              fill=fill, linecolor=linecolor, label=sublabel,
#     437                              zorder=element_zorder, color=element_color,
# --> 438                              bins=bins, **kwargs)
#     439
#     440
#
# /usr/local/lib/python3.7/site-packages/joypy/joyplot.py in plot_density(ax, x_range, v, kind, bw_method, bins, fill, linecolor, clip_on, **kwargs)
#     273
#     274     if fill:
# --> 275         ax.fill_between(x_range, 0.0, y, clip_on=clip_on, **kwargs)
#     276
#     277         # Hack to have a border at the bottom at the fill patch
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5047         x = ma.masked_invalid(self.convert_xunits(x))
#    5048         y1 = ma.masked_invalid(self.convert_yunits(y1))
# -> 5049         y2 = ma.masked_invalid(self.convert_yunits(y2))
#    5050
#    5051         for name, array in [('x', x), ('y1', y1), ('y2', y2)]:
#
# /usr/local/lib/python3.7/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2364         cls = type(a)
#    2365     else:
# -> 2366         condition = ~(np.isfinite(a))
#    2367         cls = MaskedArray
#    2368     result = a.view(cls)
#
# KeyboardInterrupt:
